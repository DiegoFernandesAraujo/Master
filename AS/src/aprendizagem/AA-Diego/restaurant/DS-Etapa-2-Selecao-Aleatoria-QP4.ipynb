# %% [markdown]
#  # Desconsiderando os registros que possuam grande concordância ou pouquíssima concordância

# %% [markdown]
# # Seleção aleatória de conjuntos

# %%
import warnings
warnings.filterwarnings('ignore')  # "error", "ignore", "always", "default", "module" or "once"
import os, errno
import re
import numpy as np
import math
import pandas as pd
import sys
from collections import Counter
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# nao_passaram = 0
# iteracoes = 0

############################################################################################################################
#Definição de funções
############################################################################################################################

#Função para geração do conjunto de treinamento
def geraTrainSet(ct, dir, file1):
    
    try:
        os.makedirs(dir)
    except OSError as e:
        if e.errno != errno.EEXIST:
            raise
        
    #Desnecessária essa parte se quiser deixar a primeira coluna com o status das duplicatas
    cols = list(ct.columns.values)
    cols.pop(cols.index('duplicata'))
    ct = ct[cols+['duplicata']]
    
    ct.to_csv(dir+file1, sep=';', index=False)     
    
#Função para geração do conjunto de teste
def geraTestSet(ct, dir, file1):
    
    try:
        os.makedirs(dir)
    except OSError as e:
        if e.errno != errno.EEXIST:
            raise
    
    #Desnecessária essa parte se quiser deixar a primeira coluna com o status das duplicatas
    cols = list(ct.columns.values)
    cols.pop(cols.index('duplicata'))
    ct = ct[cols+['duplicata']]
    
    ct.to_csv(dir+file1, sep=';', index=False)
    
    
############################

#Parâmetros do usuário (Definir entrada dos dados)
estat_ord = 'med' #Estatística para ordenamento
#qtd_alg = 23 #Quantidade total de algoritmos (Modificado para ser atualizado em cada iteração de acordo com a quantidade máxima de algoritmos em cada experimento)
qtd_alg_nd = 2 #Quantidade máxima de algoritmos para separar o conjunto de possíves não-duplicadas
# k = 3 #Tamanho da janela
# janelas = [2,3,4,5]
# janelas = [3] 
# janelas = [1, 0.01, 0.03, 0.05] # K = {1, 1%, 3%, 5%}
janelas = [0.01] #Quando houver a janela vencedora. Após testar as combinações acima
 #com todas as bases. Lembrando que só deve ser usada para as demais QP além e QP6
orcamentos = [50, 100, 150, 200]
tam_min_ct = 20
seed = 500
# nAlg = 23

etapa = '2 - AA[random]'

bases = ["restaurant"]
qps = ["qp4"] #Apenas qp4, na verdade

for base in bases:
    
    print("Base atual: {0}".format(base))
    
    for qp in qps:
        
        print("QP atual: {0}".format(qp))


        dirOrig = "../../../csv/conjuntosDS/conjuntosDivergAA/"+base+"/"+qp+"/"
        dirEstat = "../../../csv/estatisticas/"+base+"/"+qp+"/"
        estat = dirEstat+"estatisticaDS.csv"

        for orcamento in orcamentos:

            dirDest = "../../../csv/conjuntosDS/treinoTeste/"+base+"/"+qp+"/"+"Random-"+str(orcamento)+"/"

            print("Orçamento atual: {0} ".format(orcamento))

            nao_passaram = 0
            iteracoes = 0

            estatisticas = pd.read_csv(estat, index_col=['algoritmosUtilizados', 'etapa', 'permutacao'], sep=';')

            ###### Criação do dataframe que armazenará as estatísticas dos conjuntos de treino e teste
            #   estat_conj = pd.DataFrame (index=['algUtl', 'permutacao'], columns=['algUtl','permutacao','tamConjTreino','prctgDup','prctgNaoDup','tamConjTeste'])
            estat_conj = pd.DataFrame (columns=['algUtl','permutacao','tamConjTreino','prctgDup','prctgNaoDup','tamConjTeste'])


            arquivos = [] #Adicionado depois

            for _, _, arquivo in os.walk(dirOrig):
                arquivos.extend(arquivo)   
                
            print(arquivos)

            for arq in arquivos:
                
                print(arq)

                if ('_NEW' in arq):# & (iteracoes <= 50):
#                 if ('diverg(10)1_NEW' in arq): # & (iteracoes <= 0): #Aqui, Diego!
#                 if (True): # & (iteracoes <= 0): #Aqui, Diego!
                    #         if ('diverg(10)18_NEW' in arq) & (iteracoes <= 0):
                    #         if ('diverg(10)18_NEW' in arq) | ('diverg(10)15_NEW' in arq) & (iteracoes <= 1):
                    print("##################################################################")
                    print("Analisando o arquivo: {0}".format(arq))
                    print("##################################################################")

                    iteracoes += 1

                    num = re.sub(r'diverg.*\)', r'', arq) #Alterar para fazer a substituição de tudo em uma linha só
                    num = num.replace('_NEW.csv','')

                    algUtl = re.sub(r'diverg.*\(', r'', arq) #Alterar para fazer a substituição de tudo em uma linha só
                    algUtl = re.sub(r'\).*', r'', algUtl) #Alterar para fazer a substituição de tudo em uma linha só
                    algUtl = int(algUtl)

                    permutacao = int(num)
                    print("permutacao: {0}".format(permutacao))

                    linhaAtual = estatisticas.xs((algUtl, '1 - acm diverg', permutacao))    

                    ###### Leitura do conjunto de pares conflitantes
                    pc = dirOrig+arq
                    
#                     print(pc)

                    pc = pd.read_csv(pc, sep=';', index_col=['elemento1', 'elemento2']) #pares conflitantes

                    cols = list(pc.columns.values)
                    cols.pop(cols.index('duplicata'))
                    pc = pc[['duplicata']+cols]

                    pc_aa = pc.iloc[:, :5 ] #Conjunto onde serão aplicadas as janelas deslizantes
                    pc_vetores = pc.iloc[:, 5: ] #Conjunto base para compor o conjunto treinamento 

                    duplicata = pc_aa.loc[:, 'duplicata' ]

                    #Adicionando a coluna de duplicatas a pc_vetores
                    pc_vetores = pd.concat([duplicata, pc_vetores], axis=1, ignore_index=False)

                    #             conj_treino = pd.DataFrame(columns=pc_vetores.columns.values)

#                     conj_treino = pc_vetores.sample(orcamento, random_state=500)
                    
                    #Apenas para criar o conjunto treino inicialmente
                    conj_treino = pc_vetores.sample(10, random_state=500)
                    orcamentoAux = orcamento
                    
                    try:
                        #O verdadeiro conj_treino deve ter o valor gerado aqui
                        conj_treino = pc_vetores.sample(orcamento, random_state=500)
                    except ValueError:
                        print("Quantidade de elementos insuficientes para realizar seleção aleatória!")
                        print("Tamanho de pc_vetores: {0} - Tamanho da amostra: {1}". format(len(pc_vetores), orcamentoAux))
                        
                        try:
                            orcamentoAux -= 10
                            conj_treino = pc_vetores.sample(orcamentoAux, random_state=500)
                        except ValueError:
                            print("Quantidade de elementos insuficientes para realizar seleção aleatória!")
                            print("Tamanho de pc_vetores: {0} - Tamanho da amostra: {1}". format(len(pc_vetores), orcamentoAux))
                            try:
                                orcamentoAux -= 10
                                conj_treino = pc_vetores.sample(orcamentoAux, random_state=500)
                            except ValueError:
                                print("Quantidade de elementos insuficientes para realizar seleção aleatória!")
                                print("Tamanho de pc_vetores: {0} - Tamanho da amostra: {1}". format(len(pc_vetores), orcamentoAux))
                                try:
                                    orcamentoAux -= 10
                                    conj_treino = pc_vetores.sample(orcamentoAux, random_state=500)
                                except ValueError:
                                    print("Quantidade de elementos insuficientes para realizar seleção aleatória!")
                                    print("Tamanho de pc_vetores: {0} - Tamanho da amostra: {1}". format(len(pc_vetores), orcamentoAux))
                                    try:
                                        orcamentoAux -= 10
                                        conj_treino = pc_vetores.sample(orcamentoAux, random_state=500)
                                    except ValueError:
                                        print("Quantidade de elementos insuficientes para realizar seleção aleatória!")
                                        print("Tamanho de pc_vetores: {0} - Tamanho da amostra: {1}". format(len(pc_vetores), orcamentoAux))
                                        try:
                                            orcamentoAux -= 10
                                            conj_treino = pc_vetores.sample(orcamentoAux, random_state=500)
                                        except ValueError:
                                            print("Quantidade de elementos insuficientes para realizar seleção aleatória!")
                                            print("Tamanho de pc_vetores: {0} - Tamanho da amostra: {1}". format(len(pc_vetores), orcamentoAux))
                                            try:
                                                orcamentoAux -= 50
                                                conj_treino = pc_vetores.sample(orcamentoAux, random_state=500)
                                            except ValueError:
                                                print("Quantidade de elementos insuficientes para realizar seleção aleatória!")
                                                print("Tamanho de pc_vetores: {0} - Tamanho da amostra: {1}". format(len(pc_vetores), orcamentoAux))
                                                try:
                                                    orcamentoAux -= 50
                                                    conj_treino = pc_vetores.sample(orcamentoAux, random_state=500)
                                                except ValueError:
                                                    print("Quantidade de elementos insuficientes para realizar seleção aleatória!")
                                                    print("Tamanho de pc_vetores: {0} - Tamanho da amostra: {1}". format(len(pc_vetores), orcamentoAux))
                                                    try:
                                                        orcamentoAux -= 50
                                                        conj_treino = pc_vetores.sample(orcamentoAux, random_state=500)
                                                    except:
                                                        print("Quantidade de elementos insuficientes para realizar seleção aleatória!")
                                                        print("Tamanho de pc_vetores: {0} - Tamanho da amostra: {1}". format(len(pc_vetores), orcamentoAux))
                                                        print('Erro na seleção aleatória para geração do conjunto de treinamento!')
                                                        exc_type, exc_obj, exc_tb = sys.exc_info()
                                                        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                                                        print(exc_type, fname, exc_tb.tb_lineno)
                                                        print(sys.exc_info())


                    iteracao = 1
                    inspecoesManuais = orcamento

                    duplicatas = [i for i in conj_treino.duplicata if i == True]
                    duplicatas = duplicatas.count(True)
                    percentDup = float(duplicatas/float(len(conj_treino))*100)
                    percentDup = float("{0:.2f}".format(percentDup))
        #             print("{0}% de duplicatas.".format(str(percentage)[:5]))

                    nao_duplicatas = [i for i in conj_treino.duplicata if i == False]
                    nao_duplicatas = nao_duplicatas.count(False)
                    percentNaoDup = float(nao_duplicatas/float(len(conj_treino))*100)
                    percentNaoDup = float("{0:.2f}".format(percentNaoDup))

                    abordagem = 'DS'

                    da = linhaAtual['da'].item()
                    dm = duplicatas
                    ndm = nao_duplicatas

                    tp = float(linhaAtual['tp'].item() + dm)
                    fp = float(linhaAtual['fp'].item())
                    tn = float(linhaAtual['tn'].item())# + ndm) #Retirado
                    fn = float(linhaAtual['fn'].item() - dm) #Adicionado

                    precision = tp/(tp+fp)
                    recall = tp/(tp+fn)
                    fmeasure = 2*((precision*recall)/(precision+recall))

                        #Adicionando valor à última linha
                    estatisticas.loc[(algUtl, etapa, permutacao), ['abordagem', 'iteracao', 'inspecoesManuais',
                        'precision', 'recall', 'f-measure', 'da', 'dm', 'ndm', 'tp',
                        'fp', 'tn', 'fn'] ] = ([abordagem, iteracao, inspecoesManuais, precision, recall, fmeasure, da, dm, ndm, tp, fp, tn, fn])
                        #algUtl = str(algUtl).replace('.0','')
                    algUtl = str(algUtl)

                    geraTrainSet(conj_treino, dirDest, 'train' + '(' + algUtl + ')' + num + '.csv')

                    #Resta para compor o conjunto teste tudo aquilo que está em pc_vetores, mas não em conj_treino
                    conj_teste = pc_vetores.loc[pc_vetores.index.difference(conj_treino.index)]
                    geraTestSet(conj_teste, dirDest, 'test' + '(' + algUtl + ')' + num + '.csv')

                    estat_conj.loc[len(estat_conj.index)] = [algUtl, permutacao, len(conj_treino), percentDup, percentNaoDup, len(conj_teste)]


            ############################################################################################################################
            #Estatísticas
            ############################################################################################################################
            #Para voltar o dataframe ao normal
            estatisticas = estatisticas.reset_index(level=['algoritmosUtilizados', 'etapa', 'permutacao'])

            estatisticas = estatisticas[['abordagem', 'etapa', 'algoritmosUtilizados', 'permutacao', 'iteracao', 'inspecoesManuais', 'precision', 'recall', 'f-measure', 'da', 'dm', 'ndm', 'tp', 'fp', 'tn', 'fn']]

            estatisticas[['algoritmosUtilizados', 'iteracao', 'inspecoesManuais', 'da', 'dm', 'ndm', 'tp', 'fp', 'tn', 'fn']] = \
            estatisticas[['algoritmosUtilizados', 'iteracao', 'inspecoesManuais', 'da', 'dm', 'ndm', 'tp', 'fp', 'tn', 'fn']].astype(int)

            estatisticas.to_csv(dirEstat+'estatisticaDS2-Random'+str(orcamento)+'.csv', sep=';', index=False)   

            estat_conj.to_csv(dirEstat+'estatisticasConjuntos-Random'+str(orcamento)+'.csv', sep=';', index=False)
# Out:
# Base atual: cd
# QP atual: qp4
# Orçamento atual: 50
# ['diverg(10)255_NEW.csv', 'diverg(15)474_NEW.csv', 'diverg(10)958_NEW.csv', 'diverg(20)653_NEW.csv', 'diverg(10)257_NEW.csv', 'diverg(20)626_NEW.csv', 'diverg(10)383_NEW.csv', 'diverg(20)584_NEW.csv', 'diverg(20)800_NEW.csv', 'diverg(10)828_NEW.csv', 'diverg(10)711_NEW.csv', 'diverg(10)297_NEW.csv', 'diverg(15)969_NEW.csv', 'diverg(20)583_NEW.csv', 'diverg(15)893_NEW.csv', 'diverg(15)50_NEW.csv', 'diverg(20)605_NEW.csv', 'diverg(20)777_NEW.csv', 'diverg(15)951_NEW.csv', 'diverg(20)104_NEW.csv', 'diverg(15)181_NEW.csv', 'diverg(15)522_NEW.csv', 'diverg(10)784_NEW.csv', 'diverg(10)97_NEW.csv', 'diverg(10)311_NEW.csv', 'diverg(15)983_NEW.csv', 'diverg(20)21_NEW.csv', 'diverg(20)452_NEW.csv', 'diverg(20)390_NEW.csv', 'diverg(15)757_NEW.csv', 'diverg(15)849_NEW.csv', 'diverg(10)747_NEW.csv', 'diverg(10)816_NEW.csv', 'diverg(15)434_NEW.csv', 'diverg(15)485_NEW.csv', 'diverg(20)9_NEW.csv', 'diverg(20)160_NEW.csv', 'diverg(20)337_NEW.csv', 'diverg(15)550_NEW.csv', 'diverg(10)182_NEW.csv', 'diverg(20)293_NEW.csv', 'diverg(20)374_NEW.csv', 'diverg(15)553_NEW.csv', 'diverg(20)762_NEW.csv', 'diverg(15)294_NEW.csv', 'diverg(20)169_NEW.csv', 'diverg(15)193_NEW.csv', 'diverg(20)408_NEW.csv', 'diverg(10)611_NEW.csv', 'diverg(10)23_NEW.csv', 'diverg(15)549_NEW.csv', 'diverg(15)11_NEW.csv', 'diverg(10)393_NEW.csv', 'diverg(10)484_NEW.csv', 'diverg(20)776_NEW.csv', 'diverg(20)363_NEW.csv', 'diverg(10)144_NEW.csv', 'diverg(15)611_NEW.csv', 'diverg(15)139_NEW.csv', 'diverg(20)326_NEW.csv', 'diverg(20)918_NEW.csv', 'diverg(20)1000_NEW.csv', 'diverg(15)138_NEW.csv', 'diverg(15)262_NEW.csv', 'diverg(20)414_NEW.csv', 'diverg(20)527_NEW.csv', 'diverg(20)204_NEW.csv', 'diverg(20)869_NEW.csv', 'diverg(20)835_NEW.csv', 'diverg(10)105_NEW.csv', 'diverg(10)955_NEW.csv', 'diverg(10)340_NEW.csv', 'diverg(15)40_NEW.csv', 'diverg(20)785_NEW.csv', 'diverg(10)162_NEW.csv', 'diverg(15)693_NEW.csv', 'diverg(10)160_NEW.csv', 'diverg(10)870_NEW.csv', 'diverg(20)226_NEW.csv', 'diverg(20)114_NEW.csv', 'diverg(20)660_NEW.csv', 'diverg(20)568_NEW.csv', 'diverg(15)815_NEW.csv', 'diverg(15)14_NEW.csv', 'diverg(20)362_NEW.csv', 'diverg(15)842_NEW.csv', 'diverg(20)42_NEW.csv', 'diverg(15)690_NEW.csv', 'diverg(15)978_NEW.csv', 'diverg(20)610_NEW.csv', 'diverg(15)784_NEW.csv', 'diverg(15)659_NEW.csv', 'diverg(15)354_NEW.csv', 'diverg(15)272_NEW.csv', 'diverg(20)649_NEW.csv', 'diverg(20)948_NEW.csv', 'diverg(10)429_NEW.csv', 'diverg(10)45_NEW.csv', 'diverg(20)36_NEW.csv', 'diverg(10)226_NEW.csv', 'diverg(20)877_NEW.csv', 'diverg(15)415_NEW.csv', 'diverg(15)334_NEW.csv', 'diverg(15)191_NEW.csv', 'diverg(20)496_NEW.csv', 'diverg(20)241_NEW.csv', 'diverg(10)98_NEW.csv', 'diverg(10)677_NEW.csv', 'diverg(10)203_NEW.csv', 'diverg(15)88_NEW.csv', 'diverg(15)46_NEW.csv', 'diverg(15)179_NEW.csv', 'diverg(10)835_NEW.csv', 'diverg(20)847_NEW.csv', 'diverg(15)913_NEW.csv', 'diverg(15)247_NEW.csv', 'diverg(15)964_NEW.csv', 'diverg(20)48_NEW.csv', 'diverg(10)554_NEW.csv', 'diverg(10)47_NEW.csv', 'diverg(10)655_NEW.csv', 'diverg(20)779_NEW.csv', 'diverg(10)146_NEW.csv', 'diverg(20)636_NEW.csv', 'diverg(15)295_NEW.csv', 'diverg(10)620_NEW.csv', 'diverg(20)798_NEW.csv', 'diverg(15)373_NEW.csv', 'diverg(10)138_NEW.csv', 'diverg(10)518_NEW.csv', 'diverg(10)291_NEW.csv', 'diverg(15)737_NEW.csv', 'diverg(20)79_NEW.csv', 'diverg(20)864_NEW.csv', 'diverg(20)934_NEW.csv', 'diverg(20)18_NEW.csv', 'diverg(15)688_NEW.csv', 'diverg(15)93_NEW.csv', 'diverg(15)531_NEW.csv', 'diverg(10)662_NEW.csv', 'diverg(15)44_NEW.csv', 'diverg(20)472_NEW.csv', 'diverg(15)370_NEW.csv', 'diverg(20)600_NEW.csv', 'diverg(20)652_NEW.csv', 'diverg(10)116_NEW.csv', 'diverg(10)726_NEW.csv', 'diverg(20)997_NEW.csv', 'diverg(20)386_NEW.csv', 'diverg(15)783_NEW.csv', 'diverg(20)974_NEW.csv', 'diverg(20)297_NEW.csv', 'diverg(10)421_NEW.csv', 'diverg(10)673_NEW.csv', 'diverg(10)811_NEW.csv', 'diverg(20)873_NEW.csv', 'diverg(15)253_NEW.csv', 'diverg(10)629_NEW.csv', 'diverg(20)13_NEW.csv', 'diverg(20)360_NEW.csv', 'diverg(10)319_NEW.c ...
# diverg(10)255_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)255_NEW.csv
# ##################################################################
# permutacao: 255
# diverg(15)474_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)474_NEW.csv
# ##################################################################
# permutacao: 474
# diverg(10)958_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)958_NEW.csv
# ##################################################################
# permutacao: 958
# diverg(20)653_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)653_NEW.csv
# ##################################################################
# permutacao: 653
# diverg(10)257_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)257_NEW.csv
# ##################################################################
# permutacao: 257
# diverg(20)626_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)626_NEW.csv
# ##################################################################
# permutacao: 626
# diverg(10)383_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)383_NEW.csv
# ##################################################################
# permutacao: 383
# diverg(20)584_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)584_NEW.csv
# ##################################################################
# permutacao: 584
# diverg(20)800_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)800_NEW.csv
# ##################################################################
# permutacao: 800
# diverg(10)828_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)828_NEW.csv
# ##################################################################
# permutacao: 828
# diverg(10)711_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)711_NEW.csv
# ##################################################################
# permutacao: 711
# diverg(10)297_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)297_NEW.csv
# ##################################################################
# permutacao: 297
# diverg(15)969_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)969_NEW.csv
# ##################################################################
# permutacao: 969
# diverg(20)583_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)583_NEW.csv
# ##################################################################
# permutacao: 583
# diverg(15)893_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)893_NEW.csv
# ##################################################################
# permutacao: 893
# diverg(15)50_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)50_NEW.csv
# ##################################################################
# permutacao: 50
# diverg(20)605_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)605_NEW.csv
# ##################################################################
# permutacao: 605
# diverg(20)777_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)777_NEW.csv
# ##################################################################
# permutacao: 777
# diverg(15)951_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)951_NEW.csv
# ##################################################################
# permutacao: 951
# diverg(20)104_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)104_NEW.csv
# ##################################################################
# permutacao: 104
# diverg(15)181_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)181_NEW.csv
# ##################################################################
# permutacao: 181
# diverg(15)522_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)522_NEW.csv
# ##################################################################
# permutacao: 522
# diverg(10)784_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)784_NEW.csv
# ##################################################################
# permutacao: 784
# diverg(10)97_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)97_NEW.csv
# ##################################################################
# permutacao: 97
# diverg(10)311_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)311_NEW.csv
# ##################################################################
# permutacao: 311
# diverg(15)983_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)983_NEW.csv
# ##################################################################
# permutacao: 983
# diverg(20)21_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)21_NEW.csv
# ##################################################################
# permutacao: 21
# diverg(20)452_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)452_NEW.csv
# ##################################################################
# permutacao: 452
# diverg(20)390_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)390_NEW.csv
# ##################################################################
# permutacao: 390
# diverg(15)757_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)757_NEW.csv
# ##################################################################
# permutacao: 757
# diverg(15)849_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)849_NEW.csv
# ##################################################################
# permutacao: 849
# diverg(10)747_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)747_NEW.csv
# ##################################################################
# permutacao: 747
# diverg(10)816_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)816_NEW.csv
# ##################################################################
# permutacao: 816
# diverg(15)434_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)434_NEW.csv
# ##################################################################
# permutacao: 434
# diverg(15)485_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)485_NEW.csv
# ##################################################################
# permutacao: 485
# diverg(20)9_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)9_NEW.csv
# ##################################################################
# permutacao: 9
# diverg(20)160_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)160_NEW.csv
# ##################################################################
# permutacao: 160
# diverg(20)337_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)337_NEW.csv
# ##################################################################
# permutacao: 337
# diverg(15)550_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)550_NEW.csv
# ##################################################################
# permutacao: 550
# diverg(10)182_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)182_NEW.csv
# ##################################################################
# permutacao: 182
# diverg(20)293_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)293_NEW.csv
# ##################################################################
# permutacao: 293
# diverg(20)374_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)374_NEW.csv
# ##################################################################
# permutacao: 374
# diverg(15)553_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)553_NEW.csv
# ##################################################################
# permutacao: 553
# diverg(20)762_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)762_NEW.csv
# ##################################################################
# permutacao: 762
# diverg(15)294_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)294_NEW.csv
# ##################################################################
# permutacao: 294
# diverg(20)169_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)169_NEW.csv
# ##################################################################
# permutacao: 169
# diverg(15)193_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)193_NEW.csv
# ##################################################################
# permutacao: 193
# diverg(20)408_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)408_NEW.csv
# ##################################################################
# permutacao: 408
# diverg(10)611_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)611_NEW.csv
# ##################################################################
# permutacao: 611
# diverg(10)23_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)23_NEW.csv
# ##################################################################
# permutacao: 23
# diverg(15)549_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)549_NEW.csv
# ##################################################################
# permutacao: 549
# diverg(15)11_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)11_NEW.csv
# ##################################################################
# permutacao: 11
# diverg(10)393_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)393_NEW.csv
# ##################################################################
# permutacao: 393
# diverg(10)484_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)484_NEW.csv
# ##################################################################
# permutacao: 484
# diverg(20)776_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)776_NEW.csv
# ##################################################################
# permutacao: 776
# diverg(20)363_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)363_NEW.csv
# ##################################################################
# permutacao: 363
# diverg(10)144_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)144_NEW.csv
# ##################################################################
# permutacao: 144
# diverg(15)611_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)611_NEW.csv
# ##################################################################
# permutacao: 611
# diverg(15)139_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)139_NEW.csv
# ##################################################################
# permutacao: 139
# diverg(20)326_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)326_NEW.csv
# ##################################################################
# permutacao: 326
# diverg(20)918_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)918_NEW.csv
# ##################################################################
# permutacao: 918
# diverg(20)1000_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)1000_NEW.csv
# ##################################################################
# permutacao: 1000
# diverg(15)138_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)138_NEW.csv
# ##################################################################
# permutacao: 138
# diverg(15)262_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)262_NEW.csv
# ##################################################################
# permutacao: 262
# diverg(20)414_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)414_NEW.csv
# ##################################################################
# permutacao: 414
# diverg(20)527_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)527_NEW.csv
# ##################################################################
# permutacao: 527
# diverg(20)204_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)204_NEW.csv
# ##################################################################
# permutacao: 204
# diverg(20)869_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)869_NEW.csv
# ##################################################################
# permutacao: 869
# diverg(20)835_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)835_NEW.csv
# ##################################################################
# permutacao: 835
# diverg(10)105_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)105_NEW.csv
# ##################################################################
# permutacao: 105
# diverg(10)955_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)955_NEW.csv
# ##################################################################
# permutacao: 955
# diverg(10)340_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)340_NEW.csv
# ##################################################################
# permutacao: 340
# diverg(15)40_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)40_NEW.csv
# ##################################################################
# permutacao: 40
# diverg(20)785_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)785_NEW.csv
# ##################################################################
# permutacao: 785
# diverg(10)162_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)162_NEW.csv
# ##################################################################
# permutacao: 162
# diverg(15)693_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)693_NEW.csv
# ##################################################################
# permutacao: 693
# diverg(10)160_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)160_NEW.csv
# ##################################################################
# permutacao: 160
# diverg(10)870_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)870_NEW.csv
# ##################################################################
# permutacao: 870
# diverg(20)226_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)226_NEW.csv
# ##################################################################
# permutacao: 226
# diverg(20)114_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)114_NEW.csv
# ##################################################################
# permutacao: 114
# diverg(20)660_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)660_NEW.csv
# ##################################################################
# permutacao: 660
# diverg(20)568_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)568_NEW.csv
# ##################################################################
# permutacao: 568
# diverg(15)815_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)815_NEW.csv
# ##################################################################
# permutacao: 815
# diverg(15)14_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)14_NEW.csv
# ##################################################################
# permutacao: 14
# diverg(20)362_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)362_NEW.csv
# ##################################################################
# permutacao: 362
# diverg(15)842_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)842_NEW.csv
# ##################################################################
# permutacao: 842
# diverg(20)42_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)42_NEW.csv
# ##################################################################
# permutacao: 42
# diverg(15)690_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)690_NEW.csv
# ##################################################################
# permutacao: 690
# diverg(15)978_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)978_NEW.csv
# ##################################################################
# permutacao: 978
# diverg(20)610_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)610_NEW.csv
# ##################################################################
# permutacao: 610
# diverg(15)784_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)784_NEW.csv
# ##################################################################
# permutacao: 784
# diverg(15)659_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)659_NEW.csv
# ##################################################################
# permutacao: 659
# diverg(15)354_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)354_NEW.csv
# ##################################################################
# permutacao: 354
# diverg(15)272_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)272_NEW.csv
# ##################################################################
# permutacao: 272
# diverg(20)649_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)649_NEW.csv
# ##################################################################
# permutacao: 649
# diverg(20)948_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)948_NEW.csv
# ##################################################################
# permutacao: 948
# diverg(10)429_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)429_NEW.csv
# ##################################################################
# permutacao: 429
# diverg(10)45_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)45_NEW.csv
# ##################################################################
# permutacao: 45
# diverg(20)36_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)36_NEW.csv
# ##################################################################
# permutacao: 36
# diverg(10)226_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)226_NEW.csv
# ##################################################################
# permutacao: 226
# diverg(20)877_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)877_NEW.csv
# ##################################################################
# permutacao: 877
# diverg(15)415_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)415_NEW.csv
# ##################################################################
# permutacao: 415
# diverg(15)334_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)334_NEW.csv
# ##################################################################
# permutacao: 334
# diverg(15)191_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)191_NEW.csv
# ##################################################################
# permutacao: 191
# diverg(20)496_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)496_NEW.csv
# ##################################################################
# permutacao: 496
# diverg(20)241_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)241_NEW.csv
# ##################################################################
# permutacao: 241
# diverg(10)98_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)98_NEW.csv
# ##################################################################
# permutacao: 98
# diverg(10)677_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)677_NEW.csv
# ##################################################################
# permutacao: 677
# diverg(10)203_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)203_NEW.csv
# ##################################################################
# permutacao: 203
# diverg(15)88_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)88_NEW.csv
# ##################################################################
# permutacao: 88
# diverg(15)46_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)46_NEW.csv
# ##################################################################
# permutacao: 46
# diverg(15)179_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)179_NEW.csv
# ##################################################################
# permutacao: 179
# diverg(10)835_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)835_NEW.csv
# ##################################################################
# permutacao: 835
# diverg(20)847_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)847_NEW.csv
# ##################################################################
# permutacao: 847
# diverg(15)913_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)913_NEW.csv
# ##################################################################
# permutacao: 913
# diverg(15)247_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)247_NEW.csv
# ##################################################################
# permutacao: 247
# diverg(15)964_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)964_NEW.csv
# ##################################################################
# permutacao: 964
# diverg(20)48_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)48_NEW.csv
# ##################################################################
# permutacao: 48
# diverg(10)554_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)554_NEW.csv
# ##################################################################
# permutacao: 554
# diverg(10)47_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)47_NEW.csv
# ##################################################################
# permutacao: 47
# diverg(10)655_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)655_NEW.csv
# ##################################################################
# permutacao: 655
# diverg(20)779_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)779_NEW.csv
# ##################################################################
# permutacao: 779
# diverg(10)146_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)146_NEW.csv
# ##################################################################
# permutacao: 146
# diverg(20)636_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)636_NEW.csv
# ##################################################################
# permutacao: 636
# diverg(15)295_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)295_NEW.csv
# ##################################################################
# permutacao: 295
# diverg(10)620_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)620_NEW.csv
# ##################################################################
# permutacao: 620
# diverg(20)798_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)798_NEW.csv
# ##################################################################
# permutacao: 798
# diverg(15)373_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)373_NEW.csv
# ##################################################################
# permutacao: 373
# diverg(10)138_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)138_NEW.csv
# ##################################################################
# permutacao: 138
# diverg(10)518_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)518_NEW.csv
# ##################################################################
# permutacao: 518
# diverg(10)291_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)291_NEW.csv
# ##################################################################
# permutacao: 291
# diverg(15)737_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)737_NEW.csv
# ##################################################################
# permutacao: 737
# diverg(20)79_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)79_NEW.csv
# ##################################################################
# permutacao: 79
# diverg(20)864_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)864_NEW.csv
# ##################################################################
# permutacao: 864
# diverg(20)934_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)934_NEW.csv
# ##################################################################
# permutacao: 934
# diverg(20)18_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)18_NEW.csv
# ##################################################################
# permutacao: 18
# diverg(15)688_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)688_NEW.csv
# ##################################################################
# permutacao: 688
# diverg(15)93_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)93_NEW.csv
# ##################################################################
# permutacao: 93
# diverg(15)531_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)531_NEW.csv
# ##################################################################
# permutacao: 531
# diverg(10)662_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)662_NEW.csv
# ##################################################################
# permutacao: 662
# diverg(15)44_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)44_NEW.csv
# ##################################################################
# permutacao: 44
# diverg(20)472_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)472_NEW.csv
# ##################################################################
# permutacao: 472
# diverg(15)370_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)370_NEW.csv
# ##################################################################
# permutacao: 370
# diverg(20)600_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)600_NEW.csv
# ##################################################################
# permutacao: 600
# diverg(20)652_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)652_NEW.csv
# ##################################################################
# permutacao: 652
# diverg(10)116_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)116_NEW.csv
# ##################################################################
# permutacao: 116
# diverg(10)726_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)726_NEW.csv
# ##################################################################
# permutacao: 726
# diverg(20)997_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)997_NEW.csv
# ##################################################################
# permutacao: 997
# diverg(20)386_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)386_NEW.csv
# ##################################################################
# permutacao: 386
# diverg(15)783_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)783_NEW.csv
# ##################################################################
# permutacao: 783
# diverg(20)974_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)974_NEW.csv
# ##################################################################
# permutacao: 974
# diverg(20)297_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)297_NEW.csv
# ##################################################################
# permutacao: 297
# diverg(10)421_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)421_NEW.csv
# ##################################################################
# permutacao: 421
# diverg(10)673_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)673_NEW.csv
# ##################################################################
# permutacao: 673
# diverg(10)811_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)811_NEW.csv
# ##################################################################
# permutacao: 811
# diverg(20)873_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)873_NEW.csv
# ##################################################################
# permutacao: 873
# diverg(15)253_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)253_NEW.csv
# ##################################################################
# permutacao: 253
# diverg(10)629_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)629_NEW.csv
# ##################################################################
# permutacao: 629
# diverg(20)13_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)13_NEW.csv
# ##################################################################
# permutacao: 13
# diverg(20)360_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)360_NEW.csv
# ##################################################################
# permutacao: 360
# diverg(10)319_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)319_NEW.csv
# ##################################################################
# permutacao: 319
# diverg(15)799_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)799_NEW.csv
# ##################################################################
# permutacao: 799
# diverg(20)690_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)690_NEW.csv
# ##################################################################
# permutacao: 690
# diverg(10)414_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)414_NEW.csv
# ##################################################################
# permutacao: 414
# diverg(15)568_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)568_NEW.csv
# ##################################################################
# permutacao: 568
# diverg(15)610_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)610_NEW.csv
# ##################################################################
# permutacao: 610
# diverg(15)416_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)416_NEW.csv
# ##################################################################
# permutacao: 416
# diverg(15)823_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)823_NEW.csv
# ##################################################################
# permutacao: 823
# diverg(20)855_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)855_NEW.csv
# ##################################################################
# permutacao: 855
# diverg(15)340_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)340_NEW.csv
# ##################################################################
# permutacao: 340
# diverg(20)464_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)464_NEW.csv
# ##################################################################
# permutacao: 464
# diverg(20)616_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)616_NEW.csv
# ##################################################################
# permutacao: 616
# diverg(10)77_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)77_NEW.csv
# ##################################################################
# permutacao: 77
# diverg(10)125_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)125_NEW.csv
# ##################################################################
# permutacao: 125
# diverg(10)460_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)460_NEW.csv
# ##################################################################
# permutacao: 460
# diverg(20)238_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)238_NEW.csv
# ##################################################################
# permutacao: 238
# diverg(15)566_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)566_NEW.csv
# ##################################################################
# permutacao: 566
# diverg(20)470_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)470_NEW.csv
# ##################################################################
# permutacao: 470
# diverg(10)555_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)555_NEW.csv
# ##################################################################
# permutacao: 555
# diverg(15)546_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)546_NEW.csv
# ##################################################################
# permutacao: 546
# diverg(20)712_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)712_NEW.csv
# ##################################################################
# permutacao: 712
# diverg(20)93_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)93_NEW.csv
# ##################################################################
# permutacao: 93
# diverg(20)708_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)708_NEW.csv
# ##################################################################
# permutacao: 708
# diverg(10)586_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)586_NEW.csv
# ##################################################################
# permutacao: 586
# diverg(15)103_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)103_NEW.csv
# ##################################################################
# permutacao: 103
# diverg(20)902_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)902_NEW.csv
# ##################################################################
# permutacao: 902
# diverg(20)794_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)794_NEW.csv
# ##################################################################
# permutacao: 794
# diverg(20)591_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)591_NEW.csv
# ##################################################################
# permutacao: 591
# diverg(15)956_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)956_NEW.csv
# ##################################################################
# permutacao: 956
# diverg(20)899_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)899_NEW.csv
# ##################################################################
# permutacao: 899
# diverg(15)782_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)782_NEW.csv
# ##################################################################
# permutacao: 782
# diverg(20)924_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)924_NEW.csv
# ##################################################################
# permutacao: 924
# diverg(15)276_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)276_NEW.csv
# ##################################################################
# permutacao: 276
# diverg(20)598_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)598_NEW.csv
# ##################################################################
# permutacao: 598
# diverg(10)867_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)867_NEW.csv
# ##################################################################
# permutacao: 867
# diverg(20)185_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)185_NEW.csv
# ##################################################################
# permutacao: 185
# diverg(20)566_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)566_NEW.csv
# ##################################################################
# permutacao: 566
# diverg(15)705_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)705_NEW.csv
# ##################################################################
# permutacao: 705
# diverg(15)9_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)9_NEW.csv
# ##################################################################
# permutacao: 9
# diverg(15)94_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)94_NEW.csv
# ##################################################################
# permutacao: 94
# diverg(10)651_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)651_NEW.csv
# ##################################################################
# permutacao: 651
# diverg(10)836_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)836_NEW.csv
# ##################################################################
# permutacao: 836
# diverg(10)980_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)980_NEW.csv
# ##################################################################
# permutacao: 980
# diverg(15)942_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)942_NEW.csv
# ...
# ##################################################################
# permutacao: 53
# diverg(20)645_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)645_NEW.csv
# ##################################################################
# permutacao: 645
# diverg(10)668_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)668_NEW.csv
# ##################################################################
# permutacao: 668
# diverg(15)290_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)290_NEW.csv
# ##################################################################
# permutacao: 290
# diverg(20)500_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)500_NEW.csv
# ##################################################################
# permutacao: 500
# diverg(20)208_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)208_NEW.csv
# ##################################################################
# permutacao: 208
# diverg(20)726_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)726_NEW.csv
# ##################################################################
# permutacao: 726
# diverg(20)346_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)346_NEW.csv
# ##################################################################
# permutacao: 346
# diverg(20)263_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)263_NEW.csv
# ##################################################################
# permutacao: 263
# diverg(10)901_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)901_NEW.csv
# ##################################################################
# permutacao: 901
# diverg(15)362_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)362_NEW.csv
# ##################################################################
# permutacao: 362
# diverg(15)168_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)168_NEW.csv
# ##################################################################
# permutacao: 168
# diverg(10)227_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)227_NEW.csv
# ##################################################################
# permutacao: 227
# diverg(10)21_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)21_NEW.csv
# ##################################################################
# permutacao: 21
# diverg(15)682_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)682_NEW.csv
# ##################################################################
# permutacao: 682
# diverg(15)512_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)512_NEW.csv
# ##################################################################
# permutacao: 512
# diverg(20)570_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)570_NEW.csv
# ##################################################################
# permutacao: 570
# diverg(10)556_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)556_NEW.csv
# ##################################################################
# permutacao: 556
# diverg(15)822_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)822_NEW.csv
# ##################################################################
# permutacao: 822
# diverg(20)742_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)742_NEW.csv
# ##################################################################
# permutacao: 742
# diverg(15)308_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)308_NEW.csv
# ##################################################################
# permutacao: 308
# diverg(10)14_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)14_NEW.csv
# ##################################################################
# permutacao: 14
# diverg(20)890_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)890_NEW.csv
# ##################################################################
# permutacao: 890
# diverg(15)529_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)529_NEW.csv
# ##################################################################
# permutacao: 529
# diverg(20)594_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)594_NEW.csv
# ##################################################################
# permutacao: 594
# diverg(10)154_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)154_NEW.csv
# ##################################################################
# permutacao: 154
# diverg(15)880_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)880_NEW.csv
# ##################################################################
# permutacao: 880
# diverg(20)829_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)829_NEW.csv
# ##################################################################
# permutacao: 829
# diverg(20)628_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)628_NEW.csv
# ##################################################################
# permutacao: 628
# diverg(15)644_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)644_NEW.csv
# ##################################################################
# permutacao: 644
# diverg(10)217_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)217_NEW.csv
# ##################################################################
# permutacao: 217
# diverg(15)332_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)332_NEW.csv
# ##################################################################
# permutacao: 332
# diverg(15)732_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)732_NEW.csv
# ##################################################################
# permutacao: 732
# diverg(10)489_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)489_NEW.csv
# ##################################################################
# permutacao: 489
# diverg(10)101_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)101_NEW.csv
# ##################################################################
# permutacao: 101
# diverg(15)177_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)177_NEW.csv
# ##################################################################
# permutacao: 177
# diverg(15)127_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)127_NEW.csv
# ##################################################################
# permutacao: 127
# diverg(20)897_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)897_NEW.csv
# ##################################################################
# permutacao: 897
# diverg(15)658_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)658_NEW.csv
# ##################################################################
# permutacao: 658
# diverg(15)429_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)429_NEW.csv
# ##################################################################
# permutacao: 429
# diverg(20)801_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)801_NEW.csv
# ##################################################################
# permutacao: 801
# diverg(10)415_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)415_NEW.csv
# ##################################################################
# permutacao: 415
# diverg(10)377_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)377_NEW.csv
# ##################################################################
# permutacao: 377
# diverg(10)464_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)464_NEW.csv
# ##################################################################
# permutacao: 464
# diverg(20)103_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)103_NEW.csv
# ##################################################################
# permutacao: 103
# diverg(20)409_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)409_NEW.csv
# ##################################################################
# permutacao: 409
# diverg(20)5_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)5_NEW.csv
# ##################################################################
# permutacao: 5
# diverg(10)1000_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)1000_NEW.csv
# ##################################################################
# permutacao: 1000
# diverg(20)89_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)89_NEW.csv
# ##################################################################
# permutacao: 89
# diverg(20)14_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)14_NEW.csv
# ##################################################################
# permutacao: 14
# diverg(20)109_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)109_NEW.csv
# ##################################################################
# permutacao: 109
# diverg(10)143_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)143_NEW.csv
# ##################################################################
# permutacao: 143
# diverg(15)464_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)464_NEW.csv
# ##################################################################
# permutacao: 464
# diverg(20)8_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)8_NEW.csv
# ##################################################################
# permutacao: 8
# diverg(10)820_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)820_NEW.csv
# ##################################################################
# permutacao: 820
# diverg(10)354_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)354_NEW.csv
# ##################################################################
# permutacao: 354
# diverg(15)111_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)111_NEW.csv
# ##################################################################
# permutacao: 111
# diverg(10)513_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)513_NEW.csv
# ##################################################################
# permutacao: 513
# diverg(20)338_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)338_NEW.csv
# ##################################################################
# permutacao: 338
# diverg(10)724_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)724_NEW.csv
# ##################################################################
# permutacao: 724
# diverg(20)575_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)575_NEW.csv
# ##################################################################
# permutacao: 575
# diverg(15)349_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)349_NEW.csv
# ##################################################################
# permutacao: 349
# diverg(15)188_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)188_NEW.csv
# ##################################################################
# permutacao: 188
# diverg(10)462_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)462_NEW.csv
# ##################################################################
# permutacao: 462
# Quantidade de elementos insuficientes para realizar seleção aleatória!
# Tamanho de pc_vetores: 177 - Tamanho da amostra: 200
# Quantidade de elementos insuficientes para realizar seleção aleatória!
# Tamanho de pc_vetores: 177 - Tamanho da amostra: 190
# Quantidade de elementos insuficientes para realizar seleção aleatória!
# Tamanho de pc_vetores: 177 - Tamanho da amostra: 180
# diverg(20)351_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)351_NEW.csv
# ##################################################################
# permutacao: 351
# diverg(10)768_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)768_NEW.csv
# ##################################################################
# permutacao: 768
# diverg(15)238_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)238_NEW.csv
# ##################################################################
# permutacao: 238
# diverg(15)62_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)62_NEW.csv
# ##################################################################
# permutacao: 62
# diverg(15)58_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)58_NEW.csv
# ##################################################################
# permutacao: 58
# diverg(10)854_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)854_NEW.csv
# ##################################################################
# permutacao: 854
# diverg(20)887_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(20)887_NEW.csv
# ##################################################################
# permutacao: 887
# diverg(10)929_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(10)929_NEW.csv
# ##################################################################
# permutacao: 929
# diverg(15)528_NEW.csv
# ##################################################################
# Analisando o arquivo: diverg(15)528_NEW.csv
# ##################################################################
# permutacao: 528
