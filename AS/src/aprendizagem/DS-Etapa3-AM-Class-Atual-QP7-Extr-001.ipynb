# %% [markdown]
# #  Classificação a partir de conjuntos de treinamento gerados em QP6 - Janela 0.01 - Extremos

# %%
# import warnings
# warnings.filterwarnings('ignore')  # "error", "ignore", "always", "default", "module" or "once"
import numpy as np
import math
import pandas as pd
import matplotlib
# %matplotlib inline
import sys
import os
import glob
import re

# janelas = [1, 0.01, 0.03, 0.05] # K = {1, 1%, 3%, 5%}
# janelas = [0.01] #Quando houver a janela vencedora. Após testar as combinações acima
                 #com todas as bases. Lembrando que só deve ser usada para as demais QP além e QP6

# regioes = ["incert", "extrm"]
regioes = ["extrm"] #Incerteza eu já tenho de QP6
# bases = ["cds", "cds1", "cds2"]
bases = ["cd"]
qps = ["qp7"] #Apenas QP7.
k = 0.01


for base in bases:
    
    print("Base atual: {0}".format(base))
    
    for qp in qps:
        
        print("QP atual: {0}".format(qp))
    
        for regiao in regioes: #Essa repetição vai ser necessária apenas para QP6

            abordagemAA = '2 - AA[dg-arj]' #'2 - AA[pet-chr]' ou '2 - AA[dg-arj]'
#             dirOrig = "../csv/conjuntosDS/treinoTeste/"+base+"/"+qp+"/"+"DgArj-"+regiao+"/"
            dirOrig = "../csv/conjuntosDS/treinoTeste/"+base+"/"+qp+"/"+"/DgArj-"+regiao+"-k"+str(k)+"/"
        #     dirOrig = "../csv/conjuntosDS/treinoTeste-k"+str(k)+"/"
            # dirOrig = "c:/Users/Diego/Documents/NetBeansProjects/Master-SKYAM/AS/src/csv/conjuntosDS/treinoTeste/"
            # dirOrig = "../arqResult/csv/conjuntosDS/conjuntosDiverg/treinoTeste/"
            # estat = "../csv/estatisticaDS2.csv"
            dirEstat = "../csv/estatisticas/"+base+"/"+qp+"/"
#             estat = dirEstat+"estatisticaDS2-DgArj-"+regiao+".csv" #Antes de variar as janelas
            estat = dirEstat+"estatisticaDS2-DgArj-"+regiao+"-k"+str(k)+".csv"
    #         estat = "../csv/estatisticaDS2-DgArj-k"+str(k)+".csv"
            # estat = "c:/Users/Diego/Documents/NetBeansProjects/Master-SKYAM/AS/src/csv/estatisticaDS2.csv"
            # estat = "../arqResult/csv/estatisticaDS2.csv"

            print(dirOrig)

            etapa = '3 - clasf'

            # estatisticas = pd.read_csv(estat, index_col=['etapa','permutacao'], sep=';')
            estatisticas = pd.read_csv(estat, index_col=['algoritmosUtilizados','permutacao','etapa'], sep=';')
        #     estatisticas.tail()

            arquivos = os.listdir(dirOrig)
            # print(arquivos)
            #print(len(arquivos))

            train = []
            test = []

            for arq in arquivos:
                if arq.startswith("train"):
                    train.append(arq)
                elif arq.startswith("test"):
                    test.append(arq)

            # print('tamanho de train: %d' %(len(train)))        

            # print('tamanho de test: %d' %(len(test)))

            # print (train)    
            # print (test)    



            #lista = ['10', '15', '20', '25'] #Assumindo que serão esses os conjuntos de algoritmos
            #ATENÇÃO, DIEGO!! ISSO MUDA PARA QP2 E QP3
            lista = ['10', '15', '20'] #Assumindo que serão esses os conjuntos de algoritmos 
        #     lista = ['10'] #Assumindo que serão esses os conjuntos de algoritmos
            # lista = ['3'] #Assumindo que serão esses os conjuntos de algoritmos
            
            ####CLASSIFICAÇÃO COM RANDOM FOREST

            for i in lista: 

                cont = 0

                trainAtual = []
                testAtual = []

                for arq in train:
                    if '('+i+')' in arq:
        #             if 'train(10)22' in arq:    
                        trainAtual.append(arq)
                for arq in test:
                    if '('+i+')' in arq:
        #             if 'test(10)22' in arq:
                        testAtual.append(arq)

            #     print('lista desordenada')
            #     print(trainAtual)

            #     print('tamanho antes: %d' %(len(trainAtual)))

                #Ordenando a lista
                trainAtual = sorted(trainAtual)
                testAtual = sorted(testAtual)

            #     for x in trainAtual:
            #         print(x)



            # #     print('lista ordenada')
            # #     print(trainAtual)

            #     print('tamanho depois: %d' %(len(trainAtual)))

            #     print(type(trainAtual))


                print (i)

            #     print(trainAtual)
            #     print(testAtual)

                tam = len(trainAtual) #Mesma coisa para testAtual

                for pos in range(tam):
            #         print(pos)
                    print('')
                    print('##########################')
                    print('Arquivos atuais: %s e %s' %(trainAtual[pos], testAtual[pos]))
                    print('##########################')

                    treino = dirOrig+trainAtual[pos]
                    teste = dirOrig+testAtual[pos]

            #         print('treino: %s' %(treino))

            #         tp, fp, tn, fn = 0

                    num = trainAtual[pos].replace('train('+i+')','')
                    num = num.replace('.csv','')

                    cont += 1

                    print('Iteração: %d' %(cont))

            #         print('num: %s' %(num))

                    algUtl = re.sub('train.*\(', r'', trainAtual[pos]) #Alterar para fazer a substituição de tudo em uma linha só
                    algUtl = re.sub('\).*', r'', algUtl) #Alterar para fazer a substituição de tudo em uma linha só
                    algUtl = int(algUtl)


                    print('algUtl: %d' %(algUtl))

                    permutacao = int(num)
            #         linhaAtual = estatisticas.loc[('2 - AA[pet-chr]', permutacao), : ] #Armazena a linha correspondente à permutação
            #         linhaAtual = estatisticas.loc[('1 - acm diverg', permutacao), : ] #Armazena a linha correspondente à permutação
                    linhaAtual = estatisticas.loc[algUtl, permutacao, abordagemAA, : ] #Armazena a linha correspondente à permutação
        #             print (linhaAtual)
        #             print(linhaAtual.columns)

                #'''
            #         all = pd.read_csv("train.csv", index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'duplicata'), header = None)
            #         toClass = pd.read_csv("test.csv", index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'duplicata'), header = None)

            #         all = pd.read_csv(treino, index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'duplicata'), header = None)
            #         toClass = pd.read_csv(teste, index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'duplicata'), header = None)

                    all = pd.read_csv(treino, index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'track10', 'track11', 'duplicata'), header = 0) #Era header = None
                    toClass = pd.read_csv(teste, index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'track10', 'track11', 'duplicata'), header = 0) #Era header = None


                    # all['artist-title'] = all['artist'] * all['title']
                    # cols = list(all.columns.values)
                    # cols.pop(cols.index('duplicata'))
                    # all = all[cols+['duplicata']]

                    #Pesos baseados no Alg17

                    all['artist-title'] = all['artist'] * all['title']
                    all['soma-pesos'] = (all['artist']*1 + all['title']*2 + all['track01']*0.8 + all['track02']*0.8)/4.6
                    cols = list(all.columns.values)
                    cols.pop(cols.index('duplicata'))
                    all = all[cols+['duplicata']]

                    # toClass['artist-title'] = toClass['artist'] * toClass['title']
                    # cols = list(toClass.columns.values)
                    # cols.pop(cols.index('duplicata'))
                    # toClass = toClass[cols+['duplicata']]

                    #Pesos baseados no Alg17

                    toClass['artist-title'] = toClass['artist'] * toClass['title']
                    toClass['soma-pesos'] = (toClass['artist']*1 + toClass['title']*2 + toClass['track01']*0.8 + toClass['track02']*0.8)/4.6
                    cols = list(toClass.columns.values)
                    cols.pop(cols.index('duplicata'))
                    toClass = toClass[cols+['duplicata']]

                    #Separação do conjunto X do conjunto y
                    # X = all.loc[:,'title':'artist-title']
                    X = all.loc[:,'title':'soma-pesos']
                    y = all.duplicata

                    # XtoClass = toClass.loc[:,'title':'artist-title']
                    XtoClass = toClass.loc[:,'title':'soma-pesos']
                    ytoClass = toClass.duplicata

                    from sklearn import model_selection

                    X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.20, random_state=2)

                    from sklearn.ensemble import RandomForestClassifier
                    from sklearn.model_selection import StratifiedKFold
                    from sklearn.model_selection import KFold
                    from sklearn import model_selection

                    seed = 500

                    '''

                    from sklearn.linear_model import LogisticRegression
                    from sklearn.tree import DecisionTreeClassifier
                    from sklearn.neighbors import KNeighborsClassifier
                    from sklearn.svm import SVC

                    modelos = []
                    modelos.append(('LR', LogisticRegression()))
                    modelos.append(('KNN', KNeighborsClassifier()))
                    modelos.append(('RFC', DecisionTreeClassifier()))
                    modelos.append(('SVM', SVC()))
                    modelos.append(('RF', RandomForestClassifier()))



                    # Avaliação de cada modelo por vez
                    resultados = []
                    nomes = []
                    for nome, modelo in modelos:
                        kfold = StratifiedKFold(n_splits=10, random_state=seed) #Mudar para n-fold
                        cv_results = model_selection.cross_val_score(modelo, X_train, y_train, cv=kfold, scoring='f1')
                        msg = "%s: %f (%f)" % (nome, cv_results.mean(), cv_results.std()) #Iprimir em um arquivo
                        print(msg)
                    '''

                    rfc = RandomForestClassifier(random_state=12)

                    from sklearn.model_selection import GridSearchCV

                    param_grid = [{"criterion": ['gini', 'entropy'],"n_estimators": [10,25,30,35,40,45,50,100],
                                   #"max_depth": [2,3,4,5,6,7],
                                  "class_weight": ["balanced",None],
                                  "min_samples_split": [2, 5, 10]}]

                    score = 'f1'

                    print("# Tunando hiperparâmetros para %s" % score)
                    print()

                    grid = GridSearchCV(rfc, param_grid, cv=5, scoring='%s_macro' % score)
                    grid.fit(X_train, y_train)

                    print("Melhor conjunto de hiperparâmetros encontrado:")
                    print()
                    print(grid.best_params_)
                    # print()
                    # print("Grade de valores encontrados:")
                    # print()
                    medias = grid.cv_results_['mean_test_score']
                    desvios = grid.cv_results_['std_test_score']
                    # for media, desvio, params in zip(medias, desvios, grid.cv_results_['params']):
                    #     print("%0.3f (+/-%0.03f) for %r" % (media, desvio * 2, params))
                    #     print()

                    rfc = RandomForestClassifier(**grid.best_params_, random_state=500)

            #         rfc = RandomForestClassifier(parameters = grid.best_params_, random_state=12)

                    kfold = KFold(n_splits=2, random_state=seed)

                    try:

                        kfold = StratifiedKFold(n_splits=10, random_state=seed) #Mudar para n-fold #Adicionado depois!

                    except ValueError:

        #                 kfold = StratifiedKFold(n_splits=5, random_state=seed) #Tirei pra ver se melhora

        #             except ValueError:

                        kfold = KFold(n_splits=10, random_state=seed)

        #             except ValueError:

        #                 kfold = KFold(n_splits=5, random_state=seed)

        #             except ValueError:

        #                 kfold = KFold(random_state=seed) #Default n_splits = 3

        #             except ValueError:

        #                 kfold = KFold(n_splits=2, random_state=seed)

                    except:
                        print('Erro com a geração dos folds!')
                        print('Erro com o arquivo: ' + treino)
                        exc_type, exc_obj, exc_tb = sys.exc_info()
                        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                        print(exc_type, fname, exc_tb.tb_lineno)
                        print(sys.exc_info())

                    #Isso só serve para validar o uso do conjunto de treino 
                    #Não influencia no resultado final
        #             try:
        #                 cv_results2 = model_selection.cross_val_score(rfc, X_train, y_train, cv=kfold, scoring='f1')
        #                 msg = "%s com hiperparâmetros tunados: F1 = %f com desvio padrão = %f" % ('RFC', cv_results2.mean(), cv_results2.std())
        #                 print(msg)

        #             except:
        #                 print("ERRO NA VALIDAÇÃO CRUZADA!")
        #                 exc_type, exc_obj, exc_tb = sys.exc_info()
        #                 fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        #                 print(exc_type, fname, exc_tb.tb_lineno)
        #                 print(sys.exc_info())


                    rfc.fit(X_train, y_train) #Treinando o modelo
                    predicoes = rfc.predict(X_test) #Realizando a predição

            #         from sklearn.metrics import confusion_matrix
            #         matriz = confusion_matrix(y_test, predicoes)

            #         print(matriz)

                    from sklearn.metrics import classification_report
                    from sklearn.metrics import precision_recall_fscore_support

                    # print(classification_report(y_test, predicoes))
            #         prec, rec, fbeta, supp = precision_recall_fscore_support(y_test, predicoes, average=None)
            #         print ('precision: %.5f' %(prec[1]))
            #         print ('recall: %.5f' %(rec[1]))
            #         print ('f1: %.5f' %(fbeta[1]))
            #         print ('non-matches: %d - matches: %d' %(supp[0], supp[1]))
            #         print('')

                    # from sklearn.externals.six import StringIO  
                    # from IPython.display import Image  
                    # from sklearn.tree import export_graphviz
                    # import pydotplus
                    # dot_data = StringIO()
                    # export_graphviz(rfc, out_file=dot_data,  
                    #                 filled=True, rounded=True,
                    #                 special_characters=True, feature_names=X.columns)
                    # graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
                    # Image(graph.create_png())

                    predicoes = rfc.predict(XtoClass)

                    from sklearn.metrics import confusion_matrix
                    matriz = confusion_matrix(ytoClass, predicoes)
                    print(matriz)

                    this_tn, this_fp, this_fn, this_tp = 0, 0, 0, 0

                    this_tn, this_fp, this_fn, this_tp = confusion_matrix(ytoClass, predicoes).ravel()
                    print('tn, fp, fn, tp')
                    print(this_tn, this_fp, this_fn, this_tp)



                    from sklearn.metrics import classification_report
                    from sklearn.metrics import precision_recall_fscore_support

                    # print(classification_report(y_test, predicoes))
            #         prec, rec, fbeta, supp = precision_recall_fscore_support(ytoClass, predicoes, average=None)
            #         print ('precision: %.5f' %(prec[1]))
            #         print ('recall: %.5f' %(rec[1]))
            #         print ('f1: %.5f' %(fbeta[1]))
            #         print ('non-matches: %d - matches: %d' %(supp[0], supp[1]))
            #         print('')


                    ########################

                    #Atualizar as estatísticas
                    abordagem = 'DS'
                    #print 'abordagem é %s' %(abordagem)

                    #algUtl = linhaAtual['algoritmosUtilizados'].item()
                    iteracao = 2
                    inspecoesManuais = linhaAtual['inspecoesManuais'].item()
                    da = linhaAtual['da'].item() + (this_tp + this_fp) #Adiciona todos os casos positivos identificados
                    dm = linhaAtual['dm'].item()             #na predição
                    ndm = linhaAtual['ndm'].item()


                    fn = float(linhaAtual['fn'].item() - this_tp ) #Não tenho certeza se é isso
                    tp = this_tp + float(linhaAtual['tp'].item()) #+ dm) #Recuperar de toClass
#                     print('tp é igual a: %d' %(tp))

                    fp = this_fp + float(linhaAtual['fp'].item())
                    #tn = tn + float(linhaAtual['tn'].item() - tp) #+ ndm) #Recuperar de toClass
                    tn = (9762 * 9763) / 2 -(tp+fp+fn)



                    precision = tp/(tp+fp)
                    recall = tp/(tp+fn)
                    fmeasure = 2*((precision*recall)/(precision+recall))

                    #Adicionando valor à última linha
            #         estatisticas.loc[(etapa, permutacao), ['abordagem', 'algoritmosUtilizados', 'iteracao', 'inspecoesManuais',
            #            'precision', 'recall', 'f-measure', 'da', 'dm', 'ndm', 'tp',
            #            'fp', 'tn', 'fn'] ] = ([abordagem, algUtl, iteracao, inspecoesManuais,
            #            precision, recall, fmeasure, da, dm, ndm, tp, fp, tn, fn])
                    estatisticas.loc[(algUtl, permutacao, etapa), ['abordagem', 'iteracao', 'inspecoesManuais',
                        'precision', 'recall', 'f-measure', 'da', 'dm', 'ndm', 'tp',
                        'fp', 'tn', 'fn'] ] = ([abordagem, iteracao, inspecoesManuais,
                        precision, recall, fmeasure, da, dm, ndm, tp, fp, tn, fn])

                    #'''

            # estatisticas = estatisticas.reset_index(level=['etapa', 'permutacao'])
            estatisticas = estatisticas.reset_index(level=['algoritmosUtilizados', 'permutacao', 'etapa'])
            # estatisticas.head()                   
            #                    

            estatisticas = estatisticas[['abordagem', 'etapa', 'algoritmosUtilizados', 'permutacao', 'iteracao', 'inspecoesManuais', 'precision', 'recall', 'f-measure', 'da', 'dm', 'ndm', 'tp', 'fp', 'tn', 'fn']]

            estatisticas[['algoritmosUtilizados', 'iteracao', 'inspecoesManuais', 'da', 'dm', 'ndm', 'tp', 'fp', 'tn', 'fn']] = \
            estatisticas[['algoritmosUtilizados', 'iteracao', 'inspecoesManuais', 'da', 'dm', 'ndm', 'tp', 'fp', 'tn', 'fn']].astype(int)

#             dirEst = "../csv/"
            # dirEst = "c:/Users/Diego/Documents/NetBeansProjects/Master-SKYAM/AS/src/csv/"
            # dirEst = "../arqResult/csv/"


#             estatisticas.to_csv(dirEstat+'estatisticaDS3-DgArj-'+regiao+'.csv', sep=';', index=False)        
            estatisticas.to_csv(dirEstat+'estatisticaDS3-DgArj-'+regiao+'-k'+str(k)+'.csv', sep=';', index=False)        

            ####################### 
            #ATENÇÃO, DIEGO!#
            #Adicionar outro classificador aqui
            
#             print('lista aqui:')
#             print(lista)

        #Para o 2º classificador
        for regiao in regioes:


            estatisticas = pd.read_csv(estat, index_col=['algoritmosUtilizados','permutacao','etapa'], sep=';')
        #     estatisticas.tail()

            arquivos = os.listdir(dirOrig)
            # print(arquivos)
            #print(len(arquivos))

            train = []
            test = []

            for arq in arquivos:
                if arq.startswith("train"):
                    train.append(arq)
                elif arq.startswith("test"):
                    test.append(arq)

            # print('tamanho de train: %d' %(len(train)))        

            # print('tamanho de test: %d' %(len(test)))

            # print (train)    
            # print (test)    



            ####CLASSIFICAÇÃO COM KNN

            for i in lista: 

                cont = 0

                trainAtual = []
                testAtual = []

                for arq in train:
                    if '('+i+')' in arq:
        #             if 'train(10)22' in arq:    
                        trainAtual.append(arq)
                for arq in test:
                    if '('+i+')' in arq:
        #             if 'test(10)22' in arq:
                        testAtual.append(arq)

            #     print('lista desordenada')
            #     print(trainAtual)

            #     print('tamanho antes: %d' %(len(trainAtual)))

                #Ordenando a lista
                trainAtual = sorted(trainAtual)
                testAtual = sorted(testAtual)

            #     for x in trainAtual:
            #         print(x)



            # #     print('lista ordenada')
            # #     print(trainAtual)

            #     print('tamanho depois: %d' %(len(trainAtual)))

            #     print(type(trainAtual))


                print (i)

            #     print(trainAtual)
            #     print(testAtual)

                tam = len(trainAtual) #Mesma coisa para testAtual

                for pos in range(tam):
            #         print(pos)
                    print('')
                    print('##########################')
                    print('Arquivos atuais: %s e %s' %(trainAtual[pos], testAtual[pos]))
                    print('##########################')

                    treino = dirOrig+trainAtual[pos]
                    teste = dirOrig+testAtual[pos]

            #         print('treino: %s' %(treino))

            #         tp, fp, tn, fn = 0

                    num = trainAtual[pos].replace('train('+i+')','')
                    num = num.replace('.csv','')

                    cont += 1

                    print('Iteração: %d' %(cont))

            #         print('num: %s' %(num))

                    algUtl = re.sub('train.*\(', r'', trainAtual[pos]) #Alterar para fazer a substituição de tudo em uma linha só
                    algUtl = re.sub('\).*', r'', algUtl) #Alterar para fazer a substituição de tudo em uma linha só
                    algUtl = int(algUtl)


                    print('algUtl: %d' %(algUtl))

                    permutacao = int(num)
            #         linhaAtual = estatisticas.loc[('2 - AA[pet-chr]', permutacao), : ] #Armazena a linha correspondente à permutação
            #         linhaAtual = estatisticas.loc[('1 - acm diverg', permutacao), : ] #Armazena a linha correspondente à permutação
                    linhaAtual = estatisticas.loc[algUtl, permutacao, abordagemAA, : ] #Armazena a linha correspondente à permutação
        #             print (linhaAtual)
        #             print(linhaAtual.columns)

                #'''
            #         all = pd.read_csv("train.csv", index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'duplicata'), header = None)
            #         toClass = pd.read_csv("test.csv", index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'duplicata'), header = None)

            #         all = pd.read_csv(treino, index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'duplicata'), header = None)
            #         toClass = pd.read_csv(teste, index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'duplicata'), header = None)

                    all = pd.read_csv(treino, index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'track10', 'track11', 'duplicata'), header = 0) #Era header = None
                    toClass = pd.read_csv(teste, index_col=False, sep=';', names=('title', 'artist', 'track01', 'track02', 'track03', 'track10', 'track11', 'duplicata'), header = 0) #Era header = None


                    # all['artist-title'] = all['artist'] * all['title']
                    # cols = list(all.columns.values)
                    # cols.pop(cols.index('duplicata'))
                    # all = all[cols+['duplicata']]

                    #Pesos baseados no Alg17

                    all['artist-title'] = all['artist'] * all['title']
                    all['soma-pesos'] = (all['artist']*1 + all['title']*2 + all['track01']*0.8 + all['track02']*0.8)/4.6
                    cols = list(all.columns.values)
                    cols.pop(cols.index('duplicata'))
                    all = all[cols+['duplicata']]

                    # toClass['artist-title'] = toClass['artist'] * toClass['title']
                    # cols = list(toClass.columns.values)
                    # cols.pop(cols.index('duplicata'))
                    # toClass = toClass[cols+['duplicata']]

                    #Pesos baseados no Alg17

                    toClass['artist-title'] = toClass['artist'] * toClass['title']
                    toClass['soma-pesos'] = (toClass['artist']*1 + toClass['title']*2 + toClass['track01']*0.8 + toClass['track02']*0.8)/4.6
                    cols = list(toClass.columns.values)
                    cols.pop(cols.index('duplicata'))
                    toClass = toClass[cols+['duplicata']]

                    #Separação do conjunto X do conjunto y
                    # X = all.loc[:,'title':'artist-title']
                    X = all.loc[:,'title':'soma-pesos']
                    y = all.duplicata

                    # XtoClass = toClass.loc[:,'title':'artist-title']
                    XtoClass = toClass.loc[:,'title':'soma-pesos']
                    ytoClass = toClass.duplicata

                    from sklearn import model_selection

                    X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.20, random_state=2)

                    from sklearn.neighbors import KNeighborsClassifier
                    from sklearn.model_selection import StratifiedKFold
                    from sklearn.model_selection import KFold
                    from sklearn import model_selection

                    seed = 500

                    '''

                    from sklearn.linear_model import LogisticRegression
                    from sklearn.tree import DecisionTreeClassifier
                    from sklearn.neighbors import KNeighborsClassifier
                    from sklearn.svm import SVC

                    modelos = []
                    modelos.append(('LR', LogisticRegression()))
                    modelos.append(('KNN', KNeighborsClassifier()))
                    modelos.append(('RFC', DecisionTreeClassifier()))
                    modelos.append(('SVM', SVC()))
                    modelos.append(('RF', RandomForestClassifier()))



                    # Avaliação de cada modelo por vez
                    resultados = []
                    nomes = []
                    for nome, modelo in modelos:
                        kfold = StratifiedKFold(n_splits=10, random_state=seed) #Mudar para n-fold
                        cv_results = model_selection.cross_val_score(modelo, X_train, y_train, cv=kfold, scoring='f1')
                        msg = "%s: %f (%f)" % (nome, cv_results.mean(), cv_results.std()) #Iprimir em um arquivo
                        print(msg)
                    '''

                    knn = KNeighborsClassifier()

                    from sklearn.model_selection import GridSearchCV

                    param_grid = [{"weights": ['uniform', 'distance'],"n_neighbors": [3,5,7,9],
                                   #"max_depth": [2,3,4,5,6,7],
                                  "algorithm": ['ball_tree', 'kd_tree', 'brute', 'auto'],
                                  "metric": ['euclidean', 'manhattan', 'minkowski'],
                                  "p": [1,2]}]

                    score = 'f1'

                    print("# Tunando hiperparâmetros para %s" % score)
                    print()

                    knn = KNeighborsClassifier()

                    try:

                        grid = GridSearchCV(knn, param_grid, cv=5, scoring='%s_macro' % score)
                        grid.fit(X_train, y_train)

        #                 print("Melhor conjunto de hiperparâmetros encontrado:")
        #                 print()
        #                 print(grid.best_params_)
                        # print()
                        # print("Grade de valores encontrados:")
                        # print()
        #                 medias = grid.cv_results_['mean_test_score']
        #                 desvios = grid.cv_results_['std_test_score']
                        # for media, desvio, params in zip(medias, desvios, grid.cv_results_['params']):
                        #     print("%0.3f (+/-%0.03f) for %r" % (media, desvio * 2, params))
                        #     print()

                        knn = KNeighborsClassifier(**grid.best_params_)

                    except ValueError:

                        knn = KNeighborsClassifier()

            #         rfc = RandomForestClassifier(parameters = grid.best_params_, random_state=12)

                    kfold = KFold(n_splits=2, random_state=seed)

                    try:

                        kfold = StratifiedKFold(n_splits=10, random_state=seed) #Mudar para n-fold #Adicionado depois!

                    except ValueError:

        #                 kfold = StratifiedKFold(n_splits=5, random_state=seed) #Tirei pra ver se melhora

        #             except ValueError:

                        kfold = KFold(n_splits=10, random_state=seed)

        #             except ValueError:

        #                 kfold = KFold(n_splits=5, random_state=seed)

        #             except ValueError:

        #                 kfold = KFold(random_state=seed) #Default n_splits = 3

        #             except ValueError:

        #                 kfold = KFold(n_splits=2, random_state=seed)

                    except:
                        print('Erro com a geração dos folds!')
                        print('Erro com o arquivo: ' + treino)
                        exc_type, exc_obj, exc_tb = sys.exc_info()
                        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                        print(exc_type, fname, exc_tb.tb_lineno)
                        print(sys.exc_info())

                    #Isso só serve para validar o uso do conjunto de treino 
                    #Não influencia no resultado final
        #             try:
        #                 cv_results2 = model_selection.cross_val_score(rfc, X_train, y_train, cv=kfold, scoring='f1')
        #                 msg = "%s com hiperparâmetros tunados: F1 = %f com desvio padrão = %f" % ('RFC', cv_results2.mean(), cv_results2.std())
        #                 print(msg)

        #             except:
        #                 print("ERRO NA VALIDAÇÃO CRUZADA!")
        #                 exc_type, exc_obj, exc_tb = sys.exc_info()
        #                 fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        #                 print(exc_type, fname, exc_tb.tb_lineno)
        #                 print(sys.exc_info())


                    knn.fit(X_train, y_train) #Treinando o modelo
                    predicoes = knn.predict(X_test) #Realizando a predição

            #         from sklearn.metrics import confusion_matrix
            #         matriz = confusion_matrix(y_test, predicoes)

            #         print(matriz)

                    from sklearn.metrics import classification_report
                    from sklearn.metrics import precision_recall_fscore_support

                    # print(classification_report(y_test, predicoes))
            #         prec, rec, fbeta, supp = precision_recall_fscore_support(y_test, predicoes, average=None)
            #         print ('precision: %.5f' %(prec[1]))
            #         print ('recall: %.5f' %(rec[1]))
            #         print ('f1: %.5f' %(fbeta[1]))
            #         print ('non-matches: %d - matches: %d' %(supp[0], supp[1]))
            #         print('')

                    # from sklearn.externals.six import StringIO  
                    # from IPython.display import Image  
                    # from sklearn.tree import export_graphviz
                    # import pydotplus
                    # dot_data = StringIO()
                    # export_graphviz(rfc, out_file=dot_data,  
                    #                 filled=True, rounded=True,
                    #                 special_characters=True, feature_names=X.columns)
                    # graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
                    # Image(graph.create_png())

                    predicoes = knn.predict(XtoClass)

                    from sklearn.metrics import confusion_matrix
                    matriz = confusion_matrix(ytoClass, predicoes)
                    print(matriz)

                    this_tn, this_fp, this_fn, this_tp = 0, 0, 0, 0

                    this_tn, this_fp, this_fn, this_tp = confusion_matrix(ytoClass, predicoes).ravel()
                    print('tn, fp, fn, tp')
                    print(this_tn, this_fp, this_fn, this_tp)



                    from sklearn.metrics import classification_report
                    from sklearn.metrics import precision_recall_fscore_support

                    # print(classification_report(y_test, predicoes))
            #         prec, rec, fbeta, supp = precision_recall_fscore_support(ytoClass, predicoes, average=None)
            #         print ('precision: %.5f' %(prec[1]))
            #         print ('recall: %.5f' %(rec[1]))
            #         print ('f1: %.5f' %(fbeta[1]))
            #         print ('non-matches: %d - matches: %d' %(supp[0], supp[1]))
            #         print('')


                    ########################

                    #Atualizar as estatísticas
                    abordagem = 'DS'
                    #print 'abordagem é %s' %(abordagem)

                    #algUtl = linhaAtual['algoritmosUtilizados'].item()
                    iteracao = 2
                    inspecoesManuais = linhaAtual['inspecoesManuais'].item()
                    da = linhaAtual['da'].item() + (this_tp + this_fp) #Adiciona todos os casos positivos identificados
                    dm = linhaAtual['dm'].item()             #na predição
                    ndm = linhaAtual['ndm'].item()


                    fn = float(linhaAtual['fn'].item() - this_tp ) #Não tenho certeza se é isso
                    tp = this_tp + float(linhaAtual['tp'].item()) #+ dm) #Recuperar de toClass
                    print('tp é igual a: %d' %(tp))

                    fp = this_fp + float(linhaAtual['fp'].item())
                    #tn = tn + float(linhaAtual['tn'].item() - tp) #+ ndm) #Recuperar de toClass
                    tn = (9762 * 9763) / 2 -(tp+fp+fn)



                    precision = tp/(tp+fp)
                    recall = tp/(tp+fn)
                    fmeasure = 2*((precision*recall)/(precision+recall))

                    #Adicionando valor à última linha
            #         estatisticas.loc[(etapa, permutacao), ['abordagem', 'algoritmosUtilizados', 'iteracao', 'inspecoesManuais',
            #            'precision', 'recall', 'f-measure', 'da', 'dm', 'ndm', 'tp',
            #            'fp', 'tn', 'fn'] ] = ([abordagem, algUtl, iteracao, inspecoesManuais,
            #            precision, recall, fmeasure, da, dm, ndm, tp, fp, tn, fn])
                    estatisticas.loc[(algUtl, permutacao, etapa), ['abordagem', 'iteracao', 'inspecoesManuais',
                        'precision', 'recall', 'f-measure', 'da', 'dm', 'ndm', 'tp',
                        'fp', 'tn', 'fn'] ] = ([abordagem, iteracao, inspecoesManuais,
                        precision, recall, fmeasure, da, dm, ndm, tp, fp, tn, fn])

                    #'''

            # estatisticas = estatisticas.reset_index(level=['etapa', 'permutacao'])
            estatisticas = estatisticas.reset_index(level=['algoritmosUtilizados', 'permutacao', 'etapa'])
            # estatisticas.head()                   
            #                    

            estatisticas = estatisticas[['abordagem', 'etapa', 'algoritmosUtilizados', 'permutacao', 'iteracao', 'inspecoesManuais', 'precision', 'recall', 'f-measure', 'da', 'dm', 'ndm', 'tp', 'fp', 'tn', 'fn']]

            estatisticas[['algoritmosUtilizados', 'iteracao', 'inspecoesManuais', 'da', 'dm', 'ndm', 'tp', 'fp', 'tn', 'fn']] = \
            estatisticas[['algoritmosUtilizados', 'iteracao', 'inspecoesManuais', 'da', 'dm', 'ndm', 'tp', 'fp', 'tn', 'fn']].astype(int)

        #     dirEst = "../csv/"
            # dirEst = "c:/Users/Diego/Documents/NetBeansProjects/Master-SKYAM/AS/src/csv/"
            # dirEst = "../arqResult/csv/"
            
#             estatisticas.to_csv(dirEstat+'estatisticaDS3-DgArj-knn-'+regiao+'.csv', sep=';', index=False)        
            estatisticas.to_csv(dirEstat+'estatisticaDS3-DgArj-knn-'+regiao+'-k'+str(k)+'.csv', sep=';', index=False)
# Out:
# Base atual: cd
# QP atual: qp7
# ../csv/conjuntosDS/treinoTeste/cd/qp7//DgArj-extrm-k0.01/
# 10
#
# ##########################
# Arquivos atuais: train(10)1.csv e test(10)1.csv
# ##########################
# Iteração: 1
# algUtl: 10
# /root/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# # Tunando hiperparâmetros para f1
#
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[133  13]
#  [  3 188]]
# tn, fp, fn, tp
# 133 13 3 188
#
# ##########################
# Arquivos atuais: train(10)10.csv e test(10)10.csv
# ##########################
# Iteração: 2
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[329  35]
#  [  4 152]]
# tn, fp, fn, tp
# 329 35 4 152
#
# ##########################
# Arquivos atuais: train(10)100.csv e test(10)100.csv
# ##########################
# Iteração: 3
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[617  65]
#  [  9 142]]
# tn, fp, fn, tp
# 617 65 9 142
#
# ##########################
# Arquivos atuais: train(10)1000.csv e test(10)1000.csv
# ##########################
# Iteração: 4
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[266  26]
#  [  4 168]]
# tn, fp, fn, tp
# 266 26 4 168
#
# ##########################
# Arquivos atuais: train(10)101.csv e test(10)101.csv
# ##########################
# Iteração: 5
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 10, 'n_estimators': 10}
# [[ 24  14]
#  [ 21 137]]
# tn, fp, fn, tp
# 24 14 21 137
#
# ##########################
# Arquivos atuais: train(10)102.csv e test(10)102.csv
# ##########################
# Iteração: 6
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[636  48]
#  [  4 138]]
# tn, fp, fn, tp
# 636 48 4 138
#
# ##########################
# Arquivos atuais: train(10)103.csv e test(10)103.csv
# ##########################
# Iteração: 7
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': None, 'criterion': 'entropy', 'min_samples_split': 10, 'n_estimators': 100}
# [[178  10]
#  [  7 161]]
# tn, fp, fn, tp
# 178 10 7 161
#
# ##########################
# Arquivos atuais: train(10)104.csv e test(10)104.csv
# ##########################
# Iteração: 8
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 5, 'n_estimators': 10}
# [[616  53]
#  [  0 146]]
# tn, fp, fn, tp
# 616 53 0 146
#
# ##########################
# Arquivos atuais: train(10)105.csv e test(10)105.csv
# ##########################
# Iteração: 9
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[786  15]
#  [ 12 144]]
# tn, fp, fn, tp
# 786 15 12 144
#
# ##########################
# Arquivos atuais: train(10)106.csv e test(10)106.csv
# ##########################
# Iteração: 10
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[627  33]
#  [  2 168]]
# tn, fp, fn, tp
# 627 33 2 168
#
# ##########################
# Arquivos atuais: train(10)107.csv e test(10)107.csv
# ##########################
# Iteração: 11
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[267   9]
#  [  3 164]]
# tn, fp, fn, tp
# 267 9 3 164
#
# ##########################
# Arquivos atuais: train(10)108.csv e test(10)108.csv
# ##########################
# Iteração: 12
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_split': 2, 'n_estimators': 25}
# [[454 105]
#  [  7 182]]
# tn, fp, fn, tp
# 454 105 7 182
#
# ##########################
# Arquivos atuais: train(10)109.csv e test(10)109.csv
# ##########################
# Iteração: 13
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_split': 5, 'n_estimators': 10}
# [[128  13]
#  [ 11 165]]
# tn, fp, fn, tp
# 128 13 11 165
#
# ##########################
# Arquivos atuais: train(10)11.csv e test(10)11.csv
# ##########################
# Iteração: 14
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 30}
# [[681  78]
#  [  7 100]]
# tn, fp, fn, tp
# 681 78 7 100
#
# ##########################
# Arquivos atuais: train(10)110.csv e test(10)110.csv
# ##########################
# Iteração: 15
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[361 160]
#  [  8 180]]
# tn, fp, fn, tp
# 361 160 8 180
#
# ##########################
# Arquivos atuais: train(10)111.csv e test(10)111.csv
# ##########################
# Iteração: 16
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[377  50]
#  [  8 127]]
# tn, fp, fn, tp
# 377 50 8 127
#
# ##########################
# Arquivos atuais: train(10)112.csv e test(10)112.csv
# ##########################
# Iteração: 17
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_split': 2, 'n_estimators': 10}
# [[376  30]
#  [  7 175]]
# tn, fp, fn, tp
# 376 30 7 175
#
# ##########################
# Arquivos atuais: train(10)113.csv e test(10)113.csv
# ##########################
# Iteração: 18
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[593  25]
#  [  6 154]]
# tn, fp, fn, tp
# 593 25 6 154
#
# ##########################
# Arquivos atuais: train(10)114.csv e test(10)114.csv
# ##########################
# Iteração: 19
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[415  91]
#  [  6 153]]
# tn, fp, fn, tp
# 415 91 6 153
#
# ##########################
# Arquivos atuais: train(10)115.csv e test(10)115.csv
# ##########################
# Iteração: 20
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[436  32]
#  [  7 155]]
# tn, fp, fn, tp
# 436 32 7 155
#
# ##########################
# Arquivos atuais: train(10)116.csv e test(10)116.csv
# ##########################
# Iteração: 21
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_split': 2, 'n_estimators': 35}
# [[125  13]
#  [ 14 177]]
# tn, fp, fn, tp
# 125 13 14 177
#
# ##########################
# Arquivos atuais: train(10)117.csv e test(10)117.csv
# ##########################
# Iteração: 22
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[282  28]
#  [  3 172]]
# tn, fp, fn, tp
# 282 28 3 172
#
# ##########################
# Arquivos atuais: train(10)118.csv e test(10)118.csv
# ##########################
# Iteração: 23
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 30}
# [[565  12]
#  [ 13 119]]
# tn, fp, fn, tp
# 565 12 13 119
#
# ##########################
# Arquivos atuais: train(10)119.csv e test(10)119.csv
# ##########################
# Iteração: 24
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_split': 5, 'n_estimators': 10}
# [[508  35]
#  [  7 123]]
# tn, fp, fn, tp
# 508 35 7 123
#
# ##########################
# Arquivos atuais: train(10)12.csv e test(10)12.csv
# ##########################
# Iteração: 25
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[454  58]
#  [  4 153]]
# tn, fp, fn, tp
# 454 58 4 153
#
# ##########################
# Arquivos atuais: train(10)120.csv e test(10)120.csv
# ##########################
# Iteração: 26
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 40}
# [[256  24]
#  [  3 176]]
# tn, fp, fn, tp
# 256 24 3 176
#
# ##########################
# Arquivos atuais: train(10)121.csv e test(10)121.csv
# ##########################
# Iteração: 27
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[363  27]
#  [  3 169]]
# tn, fp, fn, tp
# 363 27 3 169
#
# ##########################
# Arquivos atuais: train(10)122.csv e test(10)122.csv
# ##########################
# Iteração: 28
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[647   6]
#  [  7 160]]
# tn, fp, fn, tp
# 647 6 7 160
#
# ##########################
# Arquivos atuais: train(10)123.csv e test(10)123.csv
# ##########################
# Iteração: 29
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[339  47]
#  [  5 150]]
# tn, fp, fn, tp
# 339 47 5 150
#
# ##########################
# Arquivos atuais: train(10)124.csv e test(10)124.csv
# ##########################
# Iteração: 30
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[268  27]
#  [  4 185]]
# tn, fp, fn, tp
# 268 27 4 185
#
# ##########################
# Arquivos atuais: train(10)125.csv e test(10)125.csv
# ##########################
# Iteração: 31
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[341  55]
#  [  2 139]]
# tn, fp, fn, tp
# 341 55 2 139
#
# ##########################
# Arquivos atuais: train(10)126.csv e test(10)126.csv
# ##########################
# Iteração: 32
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[251   9]
#  [ 15 144]]
# tn, fp, fn, tp
# 251 9 15 144
#
# ##########################
# Arquivos atuais: train(10)127.csv e test(10)127.csv
# ##########################
# Iteração: 33
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[365  35]
#  [  2 149]]
# tn, fp, fn, tp
# 365 35 2 149
#
# ##########################
# Arquivos atuais: train(10)128.csv e test(10)128.csv
# ##########################
# Iteração: 34
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[323   9]
#  [  4 169]]
# tn, fp, fn, tp
# 323 9 4 169
#
# ##########################
# Arquivos atuais: train(10)129.csv e test(10)129.csv
# ##########################
# Iteração: 35
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_split': 2, 'n_estimators': 10}
# [[127  11]
#  [ 17 143]]
# tn, fp, fn, tp
# 127 11 17 143
#
# ##########################
# Arquivos atuais: train(10)13.csv e test(10)13.csv
# ##########################
# Iteração: 36
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[362  10]
#  [ 18 149]]
# tn, fp, fn, tp
# 362 10 18 149
#
# ##########################
# Arquivos atuais: train(10)130.csv e test(10)130.csv
# ##########################
# Iteração: 37
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[371  57]
#  [  2 103]]
# tn, fp, fn, tp
# 371 57 2 103
#
# ##########################
# Arquivos atuais: train(10)131.csv e test(10)131.csv
# ##########################
# Iteração: 38
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[429  32]
#  [ 12 161]]
# tn, fp, fn, tp
# 429 32 12 161
#
# ##########################
# Arquivos atuais: train(10)132.csv e test(10)132.csv
# ##########################
# Iteração: 39
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 5, 'n_estimators': 10}
# [[462  13]
#  [ 29 156]]
# tn, fp, fn, tp
# 462 13 29 156
#
# ##########################
# Arquivos atuais: train(10)133.csv e test(10)133.csv
# ##########################
# Iteração: 40
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 5, 'n_estimators': 10}
# [[  4   2]
#  [  4 107]]
# tn, fp, fn, tp
# 4 2 4 107
#
# ##########################
# Arquivos atuais: train(10)134.csv e test(10)134.csv
# ##########################
# Iteração: 41
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[627  53]
#  [  9 176]]
# tn, fp, fn, tp
# 627 53 9 176
#
# ##########################
# Arquivos atuais: train(10)135.csv e test(10)135.csv
# ##########################
# Iteração: 42
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[334  32]
#  [  6 145]]
# tn, fp, fn, tp
# 334 32 6 145
#
# ##########################
# Arquivos atuais: train(10)136.csv e test(10)136.csv
# ##########################
# Iteração: 43
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[652  97]
#  [  5 175]]
# tn, fp, fn, tp
# 652 97 5 175
#
# ##########################
# Arquivos atuais: train(10)137.csv e test(10)137.csv
# ##########################
# Iteração: 44
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[334  11]
#  [ 11 163]]
# tn, fp, fn, tp
# 334 11 11 163
#
# ##########################
# Arquivos atuais: train(10)138.csv e test(10)138.csv
# ##########################
# Iteração: 45
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[197  19]
#  [ 20 135]]
# tn, fp, fn, tp
# 197 19 20 135
#
# ##########################
# Arquivos atuais: train(10)139.csv e test(10)139.csv
# ##########################
# Iteração: 46
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 30}
# [[ 38   3]
#  [  4 166]]
# tn, fp, fn, tp
# 38 3 4 166
#
# ##########################
# Arquivos atuais: train(10)14.csv e test(10)14.csv
# ##########################
# Iteração: 47
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[383  77]
#  [  2 163]]
# tn, fp, fn, tp
# 383 77 2 163
#
# ##########################
# Arquivos atuais: train(10)140.csv e test(10)140.csv
# ##########################
# Iteração: 48
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': None, 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 50}
# [[ 64   8]
#  [ 22 151]]
# tn, fp, fn, tp
# 64 8 22 151
#
# ##########################
# Arquivos atuais: train(10)141.csv e test(10)141.csv
# ##########################
# Iteração: 49
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[314  25]
#  [  4 167]]
# tn, fp, fn, tp
# 314 25 4 167
#
# ##########################
# Arquivos atuais: train(10)142.csv e test(10)142.csv
# ##########################
# Iteração: 50
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[456  12]
#  [ 11 147]]
# tn, fp, fn, tp
# 456 12 11 147
#
# ##########################
# Arquivos atuais: train(10)143.csv e test(10)143.csv
# ##########################
# Iteração: 51
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[585  48]
#  [  2 179]]
# tn, fp, fn, tp
# 585 48 2 179
#
# ##########################
# Arquivos atuais: train(10)144.csv e test(10)144.csv
# ##########################
# Iteração: 52
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[341  40]
#  [  4 172]]
# tn, fp, fn, tp
# 341 40 4 172
#
# ##########################
# Arquivos atuais: train(10)145.csv e test(10)145.csv
# ##########################
# Iteração: 53
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': None, 'criterion': 'gini', 'min_samples_split': 5, 'n_estimators': 100}
# [[ 54   6]
#  [  7 153]]
# tn, fp, fn, tp
# 54 6 7 153
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# ##########################
# Arquivos atuais: train(10)146.csv e test(10)146.csv
# ##########################
# Iteração: 54
# algUtl: 10
# # Tunando hiperparâmetros para f1
#
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[421  56]
#  [  2 193]]
# tn, fp, fn, tp
# 421 56 2 193
#
# ##########################
# Arquivos atuais: train(10)147.csv e test(10)147.csv
# ##########################
# Iteração: 55
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[374  36]
#  [ 18 163]]
# tn, fp, fn, tp
# 374 36 18 163
#
# ##########################
# Arquivos atuais: train(10)148.csv e test(10)148.csv
# ##########################
# Iteração: 56
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[189  14]
#  [ 20 152]]
# tn, fp, fn, tp
# 189 14 20 152
#
# ##########################
# Arquivos atuais: train(10)149.csv e test(10)149.csv
# ##########################
# Iteração: 57
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 5, 'n_estimators': 30}
# [[ 68  15]
#  [  8 164]]
# tn, fp, fn, tp
# 68 15 8 164
#
# ##########################
# Arquivos atuais: train(10)15.csv e test(10)15.csv
# ##########################
# Iteração: 58
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 35}
# [[394   5]
#  [ 23 164]]
# tn, fp, fn, tp
# 394 5 23 164
#
# ##########################
# Arquivos atuais: train(10)150.csv e test(10)150.csv
# ##########################
# Iteração: 59
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[136  15]
#  [  9 176]]
# tn, fp, fn, tp
# 136 15 9 176
#
# ##########################
# Arquivos atuais: train(10)151.csv e test(10)151.csv
# ##########################
# Iteração: 60
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[251  12]
#  [ 22 111]]
# tn, fp, fn, tp
# 251 12 22 111
#
# ##########################
# Arquivos atuais: train(10)152.csv e test(10)152.csv
# ##########################
# Iteração: 61
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[525  16]
#  [ 12 157]]
# tn, fp, fn, tp
# 525 16 12 157
#
# ##########################
# Arquivos atuais: train(10)153.csv e test(10)153.csv
# ##########################
# Iteração: 62
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[ 81   9]
#  [ 22 153]]
# tn, fp, fn, tp
# 81 9 22 153
#
# ##########################
# Arquivos atuais: train(10)154.csv e test(10)154.csv
# ##########################
# Iteração: 63
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_split': 2, 'n_estimators': 45}
# [[596 160]
#  [  7 132]]
# tn, fp, fn, tp
# 596 160 7 132
#
# ##########################
# Arquivos atuais: train(10)155.csv e test(10)155.csv
# ##########################
# Iteração: 64
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[  8  14]
#  [  0 102]]
# tn, fp, fn, tp
# 8 14 0 102
#
# ##########################
# Arquivos atuais: train(10)156.csv e test(10)156.csv
# ##########################
# Iteração: 65
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[340  17]
#  [  3  95]]
# tn, fp, fn, tp
# 340 17 3 95
#
# ##########################
# Arquivos atuais: train(10)157.csv e test(10)157.csv
# ##########################
# Iteração: 66
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[232  46]
#  [  7 126]]
# tn, fp, fn, tp
# 232 46 7 126
#
# ##########################
# Arquivos atuais: train(10)158.csv e test(10)158.csv
# ##########################
# Iteração: 67
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[381  33]
#  [ 11 162]]
# tn, fp, fn, tp
# 381 33 11 162
#
# ##########################
# Arquivos atuais: train(10)159.csv e test(10)159.csv
# ##########################
# Iteração: 68
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[440  43]
#  [  6 131]]
# tn, fp, fn, tp
# 440 43 6 131
#
# ##########################
# Arquivos atuais: train(10)16.csv e test(10)16.csv
# ##########################
# Iteração: 69
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_split': 10, 'n_estimators': 25}
# [[  4   5]
#  [  8 149]]
# tn, fp, fn, tp
# 4 5 8 149
#
# ##########################
# Arquivos atuais: train(10)160.csv e test(10)160.csv
# ##########################
# Iteração: 70
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[138  16]
#  [ 13 159]]
# tn, fp, fn, tp
# 138 16 13 159
#
# ##########################
# Arquivos atuais: train(10)161.csv e test(10)161.csv
# ##########################
# Iteração: 71
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[ 78  16]
#  [  7 164]]
# tn, fp, fn, tp
# 78 16 7 164
#
# ##########################
# Arquivos atuais: train(10)162.csv e test(10)162.csv
# ##########################
# Iteração: 72
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[339  50]
#  [  2 156]]
# tn, fp, fn, tp
# 339 50 2 156
#
# ##########################
# Arquivos atuais: train(10)163.csv e test(10)163.csv
# ##########################
# Iteração: 73
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[542  13]
#  [ 13 168]]
# tn, fp, fn, tp
# 542 13 13 168
#
# ##########################
# Arquivos atuais: train(10)164.csv e test(10)164.csv
# ##########################
# Iteração: 74
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[338  29]
#  [  7 172]]
# tn, fp, fn, tp
# 338 29 7 172
#
# ##########################
# Arquivos atuais: train(10)165.csv e test(10)165.csv
# ##########################
# Iteração: 75
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 35}
# [[372  15]
#  [  9 125]]
# tn, fp, fn, tp
# 372 15 9 125
#
# ##########################
# Arquivos atuais: train(10)166.csv e test(10)166.csv
# ##########################
# Iteração: 76
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[493  28]
#  [  7 130]]
# tn, fp, fn, tp
# 493 28 7 130
#
# ##########################
# Arquivos atuais: train(10)167.csv e test(10)167.csv
# ##########################
# Iteração: 77
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[433  23]
#  [ 16 167]]
# tn, fp, fn, tp
# 433 23 16 167
#
# ##########################
# Arquivos atuais: train(10)168.csv e test(10)168.csv
# ##########################
# Iteração: 78
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[411   5]
#  [ 32 155]]
# tn, fp, fn, tp
# 411 5 32 155
#
# ##########################
# Arquivos atuais: train(10)169.csv e test(10)169.csv
# ##########################
# Iteração: 79
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 10, 'n_estimators': 10}
# [[119  12]
#  [ 12 146]]
# tn, fp, fn, tp
# 119 12 12 146
#
# ##########################
# Arquivos atuais: train(10)17.csv e test(10)17.csv
# ##########################
# Iteração: 80
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[194  33]
#  [  6 163]]
# tn, fp, fn, tp
# 194 33 6 163
#
# ##########################
# Arquivos atuais: train(10)170.csv e test(10)170.csv
# ##########################
# Iteração: 81
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 35}
# [[462  54]
#  [  7 178]]
# tn, fp, fn, tp
# 462 54 7 178
#
# ##########################
# Arquivos atuais: train(10)171.csv e test(10)171.csv
# ##########################
# Iteração: 82
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[674 115]
#  [  2 167]]
# tn, fp, fn, tp
# 674 115 2 167
#
# ##########################
# Arquivos atuais: train(10)172.csv e test(10)172.csv
# ##########################
# Iteração: 83
# algUtl: 10
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[458  32]
#  [  1 172]]
# tn, fp, fn, tp
# 458 32 1 172
#
# ##########################
# Arquivos atuais: train(10)173.csv e test(10)173.csv
# ##########################
# Iteração: 84
# algUtl: 10
# # Tunando hiperparâmetros para f1
# ...
# [[516   9]
#  [ 15 166]]
# tn, fp, fn, tp
# 516 9 15 166
#
# ##########################
# Arquivos atuais: train(20)193.csv e test(20)193.csv
# ##########################
# Iteração: 106
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': None, 'criterion': 'gini', 'min_samples_split': 10, 'n_estimators': 10}
# [[805  10]
#  [ 15 159]]
# tn, fp, fn, tp
# 805 10 15 159
#
# ##########################
# Arquivos atuais: train(20)194.csv e test(20)194.csv
# ##########################
# Iteração: 107
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[805  11]
#  [ 22 153]]
# tn, fp, fn, tp
# 805 11 22 153
#
# ##########################
# Arquivos atuais: train(20)195.csv e test(20)195.csv
# ##########################
# Iteração: 108
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[598  56]
#  [  1 176]]
# tn, fp, fn, tp
# 598 56 1 176
#
# ##########################
# Arquivos atuais: train(20)196.csv e test(20)196.csv
# ##########################
# Iteração: 109
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[781  38]
#  [  6 185]]
# tn, fp, fn, tp
# 781 38 6 185
#
# ##########################
# Arquivos atuais: train(20)197.csv e test(20)197.csv
# ##########################
# Iteração: 110
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 10, 'n_estimators': 10}
# [[703 144]
#  [  9 167]]
# tn, fp, fn, tp
# 703 144 9 167
#
# ##########################
# Arquivos atuais: train(20)198.csv e test(20)198.csv
# ##########################
# Iteração: 111
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 5, 'n_estimators': 10}
# [[787  20]
#  [ 10 179]]
# tn, fp, fn, tp
# 787 20 10 179
#
# ##########################
# Arquivos atuais: train(20)199.csv e test(20)199.csv
# ##########################
# Iteração: 112
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[515  10]
#  [ 17 171]]
# tn, fp, fn, tp
# 515 10 17 171
#
# ##########################
# Arquivos atuais: train(20)2.csv e test(20)2.csv
# ##########################
# Iteração: 113
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 30}
# [[564  12]
#  [  8 179]]
# tn, fp, fn, tp
# 564 12 8 179
#
# ##########################
# Arquivos atuais: train(20)20.csv e test(20)20.csv
# ##########################
# Iteração: 114
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 100}
# [[809  12]
#  [  8 180]]
# tn, fp, fn, tp
# 809 12 8 180
#
# ##########################
# Arquivos atuais: train(20)200.csv e test(20)200.csv
# ##########################
# Iteração: 115
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 10, 'n_estimators': 30}
# [[808  13]
#  [ 22 155]]
# tn, fp, fn, tp
# 808 13 22 155
#
# ##########################
# Arquivos atuais: train(20)201.csv e test(20)201.csv
# ##########################
# Iteração: 116
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[743  24]
#  [  4 178]]
# tn, fp, fn, tp
# 743 24 4 178
#
# ##########################
# Arquivos atuais: train(20)202.csv e test(20)202.csv
# ##########################
# Iteração: 117
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 10, 'n_estimators': 30}
# [[789  15]
#  [ 12 173]]
# tn, fp, fn, tp
# 789 15 12 173
#
# ##########################
# Arquivos atuais: train(20)203.csv e test(20)203.csv
# ##########################
# Iteração: 118
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 5, 'n_estimators': 10}
# [[448 159]
#  [  5 168]]
# tn, fp, fn, tp
# 448 159 5 168
#
# ##########################
# Arquivos atuais: train(20)204.csv e test(20)204.csv
# ##########################
# Iteração: 119
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[553  15]
#  [  8 177]]
# tn, fp, fn, tp
# 553 15 8 177
#
# ##########################
# Arquivos atuais: train(20)205.csv e test(20)205.csv
# ##########################
# Iteração: 120
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[832  10]
#  [ 21 163]]
# tn, fp, fn, tp
# 832 10 21 163
#
# ##########################
# Arquivos atuais: train(20)206.csv e test(20)206.csv
# ##########################
# Iteração: 121
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_split': 2, 'n_estimators': 100}
# [[796  11]
#  [  9 176]]
# tn, fp, fn, tp
# 796 11 9 176
#
# ##########################
# Arquivos atuais: train(20)207.csv e test(20)207.csv
# ##########################
# Iteração: 122
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[789  22]
#  [  4 187]]
# tn, fp, fn, tp
# 789 22 4 187
#
# ##########################
# Arquivos atuais: train(20)208.csv e test(20)208.csv
# ##########################
# Iteração: 123
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[800  17]
#  [ 20 167]]
# tn, fp, fn, tp
# 800 17 20 167
#
# ##########################
# Arquivos atuais: train(20)209.csv e test(20)209.csv
# ##########################
# Iteração: 124
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 100}
# [[791  11]
#  [ 13 175]]
# tn, fp, fn, tp
# 791 11 13 175
#
# ##########################
# Arquivos atuais: train(20)21.csv e test(20)21.csv
# ##########################
# Iteração: 125
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 5, 'n_estimators': 100}
# [[517  16]
#  [  7 183]]
# tn, fp, fn, tp
# 517 16 7 183
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# ##########################
# Arquivos atuais: train(20)210.csv e test(20)210.csv
# ##########################
# Iteração: 126
# algUtl: 20
# # Tunando hiperparâmetros para f1
#
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[809  16]
#  [ 11 164]]
# tn, fp, fn, tp
# 809 16 11 164
#
# ##########################
# Arquivos atuais: train(20)211.csv e test(20)211.csv
# ##########################
# Iteração: 127
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': None, 'criterion': 'entropy', 'min_samples_split': 10, 'n_estimators': 10}
# [[558  15]
#  [ 11 179]]
# tn, fp, fn, tp
# 558 15 11 179
#
# ##########################
# Arquivos atuais: train(20)212.csv e test(20)212.csv
# ##########################
# Iteração: 128
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 10}
# [[668 154]
#  [ 20 151]]
# tn, fp, fn, tp
# 668 154 20 151
#
# ##########################
# Arquivos atuais: train(20)213.csv e test(20)213.csv
# ##########################
# Iteração: 129
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_split': 2, 'n_estimators': 10}
# [[736  81]
#  [  8 170]]
# tn, fp, fn, tp
# 736 81 8 170
#
# ##########################
# Arquivos atuais: train(20)214.csv e test(20)214.csv
# ##########################
# Iteração: 130
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[811  24]
#  [ 12 185]]
# tn, fp, fn, tp
# 811 24 12 185
#
# ##########################
# Arquivos atuais: train(20)215.csv e test(20)215.csv
# ##########################
# Iteração: 131
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[796  16]
#  [ 13 175]]
# tn, fp, fn, tp
# 796 16 13 175
#
# ##########################
# Arquivos atuais: train(20)216.csv e test(20)216.csv
# ##########################
# Iteração: 132
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
# Melhor conjunto de hiperparâmetros encontrado:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'min_samples_split': 2, 'n_estimators': 25}
# [[803  14]
#  [  9 179]]
# tn, fp, fn, tp
# 803 14 9 179
#
# ##########################
# Arquivos atuais: train(20)217.csv e test(20)217.csv
# ##########################
# Iteração: 133
# algUtl: 20
# # Tunando hiperparâmetros para f1
# /root/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)
